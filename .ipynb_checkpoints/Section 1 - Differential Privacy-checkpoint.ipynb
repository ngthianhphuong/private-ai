# %% [markdown]
# ## Lesson: Toy Differential Privacy - Simple Database Queries

# %% [markdown]
# In this section we're going to play around with Differential Privacy in the context of a database query. The database is going to be a VERY simple database with only one boolean column. Each row corresponds to a person. Each value corresponds to whether or not that person has a certain private attribute (such as whether they have a certain disease, or whether they are above/below a certain age). We are then going to learn how to know whether a database query over such a small database is differentially private or not - and more importantly - what techniques are at our disposal to ensure various levels of privacy
#
#
# ### First We Create a Simple Database
#
# Step one is to create our database - we're going to do this by initializing a random list of 1s and 0s (which are the entries in our database). Note - the number of entries directly corresponds to the number of people in our database.

# %%
import torch
import numpy as np
# the number of entries in our database
num_entries = 5000

db = torch.rand(num_entries) > 0.5
db
# Out:
# tensor([False,  True,  True,  ...,  True,  True,  True])

# %% [markdown]
# ## Project: Generate Parallel Databases
#
# Key to the definition of differenital privacy is the ability to ask the question "When querying a database, if I removed someone from the database, would the output of the query be any different?". Thus, in order to check this, we must construct what we term "parallel databases" which are simply databases with one entry removed.
#
# In this first project, I want you to create a list of every parallel database to the one currently contained in the "db" variable. Then, I want you to create a function which both:
#
# - creates the initial database (db)
# - creates all parallel databases

# %%
def get_parallel_db(db, remove_index):
    return torch.cat((db[:remove_index], db[remove_index+1:]))

# %%
def get_parallel_dbs(db):
    parallel_dbs = []
    
    for i in range(len(db)):
        parallel_dbs.append(get_parallel_db(db, i))
    return parallel_dbs

# %%
def create_db_and_parallels(n):
    '''Function to create an original database of size n containing 0 and 1,
    and n parallel databases, each with one less element compared to original database.
    Return:
    db: original database of size n;
    pdbs: list of n parallel databases
    '''
    db = torch.randint(0,2, size=(n,))
    pdbs = get_parallel_dbs(db)
    return db, pdbs

# %%
db, pdbs = create_db_and_parallels(5000)

# %%
len(pdbs)
# Out:
# 5000

# %% [markdown]
# # Lesson: Towards Evaluating The Differential Privacy of a Function
#
# Intuitively, we want to be able to query our database and evaluate whether or not the result of the query is leaking "private" information. As mentioned previously, this is about evaluating whether the output of a query changes when we remove someone from the database. Specifically, we want to evaluate the *maximum* amount the query changes when someone is removed (maximum over all possible people who could be removed). So, in order to evaluate how much privacy is leaked, we're going to iterate over each person in the database and measure the difference in the output of the query relative to when we query the entire database.
#
# Just for the sake of argument, let's make our first "database query" a simple sum. Aka, we're going to count the number of 1s in the database.

# %%
db, pdbs = create_db_and_parallels(5000)

# %%
def query(db):
    return db.sum()

# %%
full_db_result = query(db)

# %%
sensitivity = 0
for pdb in pdbs:
    pdb_result = query(pdb)
    
    db_distance = torch.abs(pdb_result - full_db_result)
    
    if(db_distance > sensitivity):
        sensitivity = db_distance

# %%
sensitivity
# Out:
# tensor(1)

# %% [markdown]
# # Project - Evaluating the Privacy of a Function
#
# In the last section, we measured the difference between each parallel db's query result and the query result for the entire database and then calculated the max value (which was 1). This value is called "sensitivity", and it corresponds to the function we chose for the query. Namely, the "sum" query will always have a sensitivity of exactly 1. However, we can also calculate sensitivity for other functions as well.
#
# Let's try to calculate sensitivity for the "mean" function.

# %%
def query(db):
    return torch.mean(db.float())

# %%
def sensitivity(query, n_entries):
    db, pdbs = create_db_and_parallels(5000)
    
    full_db_result = query(db)
    
    sensitivity = 0
    for pdb in pdbs:
        pdb_result = query(pdb)

        db_distance = torch.abs(pdb_result - full_db_result)

        if(db_distance > sensitivity):
            sensitivity = db_distance
    return sensitivity

# %%
sensitivity(query, 5000)
# Out:
# tensor(0.0001)

# %% [markdown]
# Wow! That sensitivity is WAY lower. Note the intuition here. "Sensitivity" is measuring how sensitive the output of the query is to a person being removed from the database. For a simple sum, this is always 1, but for the mean, removing a person is going to change the result of the query by rougly 1 divided by the size of the database (which is much smaller). Thus, "mean" is a VASTLY less "sensitive" function (query) than SUM.

# %% [markdown]
# # Project: Calculate L1 Sensitivity For Threshold
#
# In this first project, I want you to calculate the sensitivty for the "threshold" function.
#
# - First compute the sum over the database (i.e. sum(db)) and return whether that sum is greater than a certain threshold.
# - Then, I want you to create databases of size 10 and threshold of 5 and calculate the sensitivity of the function.
# - Finally, re-initialize the database 10 times and calculate the sensitivity each time.

# %%
def query(db, threshold):
    return (db.sum() > threshold).float()

# %%
def create_dbs(n_entries):
    dbs = list()
    for i in range(n_entries):
        dbs.append(torch.randint(0, 2, size=(n_entries,)))
    return dbs

# %%
def sensitivity(query, n_entries):
    dbs = create_dbs(n_entries) # pdbs contains 10 databases of size 10
    
    sensitivities = list()
    for db in dbs:
        sensitivities.append(query(db, threshold=5))
    return sensitivities

# %%
sensitivity(query, 10)
# Out:
# [tensor(0.),
#  tensor(0.),
#  tensor(1.),
#  tensor(0.),
#  tensor(1.),
#  tensor(0.),
#  tensor(1.),
#  tensor(1.),
#  tensor(0.),
#  tensor(0.)]

# %% [markdown]
# # Lesson: A Basic Differencing Attack
#
# Sadly none of the functions we've looked at so far are differentially private (despite them having varying levels of sensitivity). The most basic type of attack can be done as follows.
#
# Let's say we wanted to figure out a specific person's value in the database. All we would have to do is query for the sum of the entire database and then the sum of the entire database without that person!
#
# # Project: Perform a Differencing Attack on Row 10
#
# In this project, I want you to construct a database and then demonstrate how you can use two different sum queries to explose the value of the person represented by row 10 in the database (note, you'll need to use a database with at least 10 rows)

# %%
def query_sum(db):
    return db.sum()

# %%
def query_sum_threshold(db, threshold=4):
    return (db.sum() > threshold).float()

# %%
def sensitivity(query, n_entries):
    # create a database of size 10
    db = torch.randint(0, 2, size=(n_entries,))
    
    # query on the whole database
    db_result = query(db)
    
    # query on the database without 10th entry
    reduced_db_result = query(db[:-1])
    
    # calculate sensitivity
    return torch.abs(db_result-reduced_db_result)

# %%
sensitivity(query_sum, 10)
# Out:
# tensor(1)

# %%
sensitivity(query_sum_threshold, 10)
# Out:
# tensor(0.)

# %% [markdown]
# # Project: Local Differential Privacy
#
# As you can see, the basic sum query is not differentially private at all! In truth, differential privacy always requires a form of randomness added to the query. Let me show you what I mean.
#
# ### Randomized Response (Local Differential Privacy)
#
# Let's say I have a group of people I wish to survey about a very taboo behavior which I think they will lie about (say, I want to know if they have ever committed a certain kind of crime). I'm not a policeman, I'm just trying to collect statistics to understand the higher level trend in society. So, how do we do this? One technique is to add randomness to each person's response by giving each person the following instructions (assuming I'm asking a simple yes/no question):
#
# - Flip a coin 2 times.
# - If the first coin flip is heads, answer honestly
# - If the first coin flip is tails, answer according to the second coin flip (heads for yes, tails for no)!
#
# Thus, each person is now protected with "plausible deniability". If they answer "Yes" to the question "have you committed X crime?", then it might becasue they actually did, or it might be becasue they are answering according to a random coin flip. Each person has a high degree of protection. Furthermore, we can recover the underlying statistics with some accuracy, as the "true statistics" are simply averaged with a 50% probability. Thus, if we collect a bunch of samples and it turns out that 60% of people answer yes, then we know that the TRUE distribution is actually centered around 70%, because 70% averaged wtih 50% (a coin flip) is 60% which is the result we obtained.
#
# However, it should be noted that, especially when we only have a few samples, this comes at the cost of accuracy. This tradeoff exists across all of Differential Privacy. The greater the privacy protection (plausible deniability) the less accurate the results.
#
# Let's implement this local DP for our database before!

# %%
# create a database
db = torch.randint(0, 2, size=(1000,))

# %%
def query(database):
    return torch.mean(database.float())

# %%
def report_query(n_entries):
    db = torch.randint(0, 2, size=(n_entries,))
    first_flip = torch.randint(0, 2, size=(n_entries,))
    second_flip = torch.randint(0, 2, size=(n_entries,))
    augmented_db = db*first_flip + (1 - first_flip)*second_flip   
                                
    db_result = query(db)
    augmented_db_result = query(augmented_db)*2 - 0.5
    return db_result, augmented_db_result

# %%
print(report_query(10))
# Out:
# (tensor(0.8000), tensor(0.5000))

# %%
print(report_query(100))
# Out:
# (tensor(0.5300), tensor(0.6200))

# %%
print(report_query(1000))
# Out:
# (tensor(0.5160), tensor(0.5100))

# %%
print(report_query(10000))
# Out:
# (tensor(0.5016), tensor(0.5046))

# %% [markdown]
# # Project: Varying Amounts of Noise
#
# In this project, I want you to augment the randomized response query (the one we just wrote) to allow for varying amounts of randomness to be added. Specifically, I want you to bias the coin flip to be higher or lower and then run the same experiment.
#
# Note - this one is a bit tricker than you might expect. You need to both adjust the likelihood of the first coin flip AND the de-skewing at the end (where we create the "augmented_result" variable).

# %%
def query(database):
    return torch.mean(database.float())

# %%
def report_query(n_entries, noise):
    
    "noise: how likely the first flip will be 1"
    
    db = torch.randint(0, 2, size=(n_entries,))
    
    first_flip = (torch.rand(len(db)) > (1 - noise)).float() # random numbers from a uniform distribution on the interval [0, 1)
    second_flip = (torch.rand(len(db)) > 0.5).float()
    
    augmented_db = db*first_flip + (1 - first_flip)*second_flip   
                                
    db_result = query(db)
    
    augmented_db_result = (query(augmented_db) - 0.5*(1-noise))/noise
    
    return db_result, augmented_db_result

# %%
# if noise = 0.3: 70% the chance the first flip will be 1

# %%
report_query(n_entries=100, noise=0.1)
# Out:
# (tensor(0.4400), tensor(0.4000))

# %%
report_query(n_entries=100, noise=0.2)
# Out:
# (tensor(0.5000), tensor(0.7500))

# %%
report_query(n_entries=100, noise=0.4)
# Out:
# (tensor(0.4900), tensor(0.4500))

# %%
report_query(n_entries=100, noise=0.8)
# Out:
# (tensor(0.4900), tensor(0.5125))

# %%
report_query(n_entries=100, noise=1)
# Out:
# (tensor(0.5000), tensor(0.5000))

# %%
report_query(n_entries=10000, noise=0.1)
# Out:
# (tensor(0.4977), tensor(0.5220))

# %%
report_query(n_entries=10000, noise=0.2)
# Out:
# (tensor(0.4999), tensor(0.5200))

# %%
report_query(n_entries=10000, noise=0.4)
# Out:
# (tensor(0.5001), tensor(0.4940))

# %% [markdown]
# # Lesson: The Formal Definition of Differential Privacy
#
# The previous method of adding noise was called "Local Differentail Privacy" because we added noise to each datapoint individually. This is necessary for some situations wherein the data is SO sensitive that individuals do not trust noise to be added later. However, it comes at a very high cost in terms of accuracy.
#
# However, alternatively we can add noise AFTER data has been aggregated by a function. This kind of noise can allow for similar levels of protection with a lower affect on accuracy. However, participants must be able to trust that no-one looked at their datapoints _before_ the aggregation took place. In some situations this works out well, in others (such as an individual hand-surveying a group of people), this is less realistic.
#
# Nevertheless, global differential privacy is incredibly important because it allows us to perform differential privacy on smaller groups of individuals with lower amounts of noise. Let's revisit our sum functions.

# %%
db, pdbs = create_db_and_parallels(100)

def query(db):
    return torch.sum(db.float())

def M(db):
    query(db) + noise

query(db)
# Out:
# tensor(45.)

# %% [markdown]
# So the idea here is that we want to add noise to the output of our function. We actually have two different kinds of noise we can add - Laplacian Noise or Gaussian Noise. However, before we do so at this point we need to dive into the formal definition of Differential Privacy.
#
# ![alt text](dp_formula.png "Title")

# %% [markdown]
# _Image From: "The Algorithmic Foundations of Differential Privacy" - Cynthia Dwork and Aaron Roth - https://www.cis.upenn.edu/~aaroth/Papers/privacybook.pdf_

# %% [markdown]
# This definition does not _create_ differential privacy, instead it is a measure of how much privacy is afforded by a query M. Specifically, it's a comparison between running the query M on a database (x) and a parallel database (y). As you remember, parallel databases are defined to be the same as a full database (x) with one entry/person removed.
#
# Thus, this definition says that FOR ALL parallel databases, the maximum distance between a query on database (x) and the same query on database (y) will be e^epsilon, but that occasionally this constraint won't hold with probability delta. Thus, this theorem is called "epsilon delta" differential privacy.
#
# # Epsilon
#
# Let's unpack the intuition of this for a moment.
#
# Epsilon Zero: If a query satisfied this inequality where epsilon was set to 0, then that would mean that the query for all parallel databases outputed the exact same value as the full database. As you may remember, when we calculated the "threshold" function, often the Sensitivity was 0. In that case, the epsilon also happened to be zero.
#
# Epsilon One: If a query satisfied this inequality with epsilon 1, then the maximum distance between all queries would be 1 - or more precisely - the maximum distance between the two random distributions M(x) and M(y) is 1 (because all these queries have some amount of randomness in them, just like we observed in the last section).
#
# # Delta
#
# Delta is basically the probability that epsilon breaks. Namely, sometimes the epsilon is different for some queries than it is for others. For example, you may remember when we were calculating the sensitivity of threshold, most of the time sensitivity was 0 but sometimes it was 1. Thus, we could calculate this as "epsilon zero but non-zero delta" which would say that epsilon is perfect except for some probability of the time when it's arbitrarily higher. Note that this expression doesn't represent the full tradeoff between epsilon and delta.

# %% [markdown]
# # Lesson: How To Add Noise for Global Differential Privacy
#
# In this lesson, we're going to learn about how to take a query and add varying amounts of noise so that it satisfies a certain degree of differential privacy. In particular, we're going to leave behind the Local Differential privacy previously discussed and instead opt to focus on Global differential privacy.
#
# So, to sum up, this lesson is about adding noise to the output of our query so that it satisfies a certain epsilon-delta differential privacy threshold.
#
# There are two kinds of noise we can add - Gaussian Noise or Laplacian Noise. Generally speaking Laplacian is better, but both are still valid. Now to the hard question...
#
# ### How much noise should we add?
#
# The amount of noise necessary to add to the output of a query is a function of four things:
#
# - the type of noise (Gaussian/Laplacian)
# - the sensitivity of the query/function
# - the desired epsilon (ε)
# - the desired delta (δ)
#
# Thus, for each type of noise we're adding, we have different way of calculating how much to add as a function of sensitivity, epsilon, and delta. We're going to focus on Laplacian noise. Laplacian noise is increased/decreased according to a "scale" parameter b. We choose "b" based on the following formula.
#
# b = sensitivity(query) / epsilon
#
# In other words, if we set b to be this value, then we know that we will have a privacy leakage of <= epsilon. Furthermore, the nice thing about Laplace is that it guarantees this with delta == 0. There are some tunings where we can have very low epsilon where delta is non-zero, but we'll ignore them for now.
#
# ### Querying Repeatedly
#
# - if we query the database multiple times - we can simply add the epsilons (Even if we change the amount of noise and their epsilons are not the same).

# %% [markdown]
# # Project: Create a Differentially Private Query
#
# In this project, I want you to take what you learned in the previous lesson and create a query function which sums over the database and adds just the right amount of noise such that it satisfies an epsilon constraint. Write a query for both "sum" and for "mean". Ensure that you use the correct sensitivity measures for both.

# %%
def query_sum(db):
    return torch.sum(db.float())

# %%
def query_mean(db):
    return torch.mean(db.float())

# %%
db, pdbs = create_db_and_parallels(5000)

# %%
def laplacian_mechanism(query, db, sensitivity, epsilon):
    beta = sensitivity/epsilon
    noise = torch.tensor(np.random.laplace(0, beta, 1))
    return query(db) + noise

# %%
laplacian_mechanism(query_sum, db, 1, 1)
# Out:
# tensor([2492.6993], dtype=torch.float64)

# %%
laplacian_mechanism(query_mean, db, 1/5000, 1)
# Out:
# tensor([0.4988], dtype=torch.float64)

# %%
# reduce epsilon - noise is more spread out
laplacian_mechanism(query_sum, db, 1, 0.001)
# Out:
# tensor([2326.1991], dtype=torch.float64)

# %%
laplacian_mechanism(query_mean, db, 1/5000, 0.001)
# Out:
# tensor([0.3998], dtype=torch.float64)

# %% [markdown]
# # Lesson: Differential Privacy for Deep Learning
#
# So in the last lessons you may have been wondering - what does all of this have to do with Deep Learning? Well, these same techniques we were just studying form the core primitives for how Differential Privacy provides guarantees in the context of Deep Learning.
#
# Previously, we defined perfect privacy as "a query to a database returns the same value even if we remove any person from the database", and used this intuition in the description of epsilon/delta. In the context of deep learning we have a similar standard.
#
# Training a model on a dataset should return the same model even if we remove any person from the dataset.
#
# Thus, we've replaced "querying a database" with "training a model on a dataset". In essence, the training process is a kind of query. However, one should note that this adds two points of complexity which database queries did not have:
#
#     1. do we always know where "people" are referenced in the dataset?
#     2. neural models rarely never train to the same output model, even on identical data
#
# The answer to (1) is to treat each training example as a single, separate person. Strictly speaking, this is often overly zealous as some training examples have no relevance to people and others may have multiple/partial (consider an image with multiple people contained within it). Thus, localizing exactly where "people" are referenced, and thus how much your model would change if people were removed, is challenging.
#
# The answer to (2) is also an open problem - but several interesitng proposals have been made. We're going to focus on one of the most popular proposals, PATE.
#
# ## An Example Scenario: A Health Neural Network
#
# First we're going to consider a scenario - you work for a hospital and you have a large collection of images about your patients. However, you don't know what's in them. You would like to use these images to develop a neural network which can automatically classify them, however since your images aren't labeled, they aren't sufficient to train a classifier.
#
# However, being a cunning strategist, you realize that you can reach out to 10 partner hospitals which DO have annotated data. It is your hope to train your new classifier on their datasets so that you can automatically label your own. While these hospitals are interested in helping, they have privacy concerns regarding information about their patients. Thus, you will use the following technique to train a classifier which protects the privacy of patients in the other hospitals.
#
# - 1) You'll ask each of the 10 hospitals to train a model on their own datasets (All of which have the same kinds of labels)
# - 2) You'll then use each of the 10 partner models to predict on your local dataset, generating 10 labels for each of your datapoints
# - 3) Then, for each local data point (now with 10 labels), you will perform a DP query to generate the final true label. This query is a "max" function, where "max" is the most frequent label across the 10 labels. We will need to add laplacian noise to make this Differentially Private to a certain epsilon/delta constraint.
# - 4) Finally, we will retrain a new model on our local dataset which now has labels. This will be our final "DP" model.
#
# So, let's walk through these steps. I will assume you're already familiar with how to train/predict a deep neural network, so we'll skip steps 1 and 2 and work with example data. We'll focus instead on step 3, namely how to perform the DP query for each example using toy data.
#
# So, let's say we have 10,000 training examples, and we've got 10 labels for each example (from our 10 "teacher models" which were trained directly on private data). Each label is chosen from a set of 10 possible labels (categories) for each image.

# %%
import numpy as np

# %%
num_teachers = 10 # we're working with 10 partner hospitals
num_examples = 10000 # the size of OUR dataset
num_labels = 10 # number of lablels for our classifier

# %%
preds = (np.random.rand(num_teachers, num_examples) * num_labels).astype(int).transpose(1,0) # fake predictions

# %%
preds[0] # predictions for first example from 10 teacher classifiers
# Out:
# array([8, 4, 6, 5, 2, 2, 3, 4, 5, 5])

# %%
preds.shape
# Out:
# (10000, 10)

# %%
new_labels = list()
for an_image in preds:

    label_counts = np.bincount(an_image, minlength=num_labels)

    epsilon = 0.1
    beta = 1 / epsilon

    for i in range(len(label_counts)):
        label_counts[i] += np.random.laplace(0, beta, 1) # add noise to prediction counts

    new_label = np.argmax(label_counts)
    
    new_labels.append(new_label)

# %%
len(new_labels)
# Out:
# 10000

# %% [markdown]
# # PATE Analysis

# %%
labels = np.array([9, 9, 3, 6, 9, 9, 9, 9, 8, 2])
counts = np.bincount(labels, minlength=10)
query_result = np.argmax(counts)
query_result
# Out:
# 9

# %%
from syft.frameworks.torch.differential_privacy import pate

# %%
num_teachers, num_examples, num_labels = (100, 100, 10)
preds = (np.random.rand(num_teachers, num_examples) * num_labels).astype(int) #fake preds
indices = (np.random.rand(num_examples) * num_labels).astype(int) # true answers

preds[:,0:10] *= 0

data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=preds, indices=indices, noise_eps=0.1, delta=1e-5)

assert data_dep_eps < data_ind_eps
# Out:
# Warning: May not have used enough values of l. Increase 'moments' variable and run again.

# %%
data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=preds, indices=indices, noise_eps=0.1, delta=1e-5)
print("Data Independent Epsilon:", data_ind_eps)
print("Data Dependent Epsilon:", data_dep_eps)
# Out:
# Warning: May not have used enough values of l. Increase 'moments' variable and run again.
# Data Independent Epsilon: 11.756462732485115
# Data Dependent Epsilon: 1.52655213289881

# %%
preds[:,0:50] *= 0

# %%
data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=preds, indices=indices, noise_eps=0.1, delta=1e-5, moments=20)
print("Data Independent Epsilon:", data_ind_eps)
print("Data Dependent Epsilon:", data_dep_eps)
# Out:
# Data Independent Epsilon: 11.756462732485115
# Data Dependent Epsilon: 0.9029013677789843

# %% [markdown]
# # Where to Go From Here
#
#
# Read:
#     - Algorithmic Foundations of Differential Privacy: https://www.cis.upenn.edu/~aaroth/Papers/privacybook.pdf
#     - Deep Learning with Differential Privacy: https://arxiv.org/pdf/1607.00133.pdf
#     - The Ethical Algorithm: https://www.amazon.com/Ethical-Algorithm-Science-Socially-Design/dp/0190948205
#
# Topics:
#     - The Exponential Mechanism
#     - The Moment's Accountant
#     - Differentially Private Stochastic Gradient Descent
#
# Advice:
#     - For deployments - stick with public frameworks!
#     - Join the Differential Privacy Community
#     - Don't get ahead of yourself - DP is still in the early days

# %% [markdown]
# # Section Project:
#
# For the final project for this section, you're going to train a DP model using this PATE method on the MNIST dataset, provided below.

# %% [markdown]
# 1. Devide teacher dataset (60000 samples) into 200 different teacher subsets, each subset contains 300 samples.
# 2. For each subset, train a classifier. There will be 200 classifiers in total.
# 3. In each subset, split into 80% train and 20% validation.
# 4. Save 200 classifiers then load them.
# 5. Use these classifiers to predict the labels for test_data (or student_data), but the training part only.
# 6. Perform PATE analysis
# 7. Build a model on student dataset. Split student dataset into 80% train and 20% test (maybe validation as well).
# 8. Train this model with created labels.
# 9. Calculate accuracy on test set, using ground truth labels.

# %% [markdown]
# ### 1. Load MNIST dataset

# %%
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import Subset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import KFold

import numpy as np
import matplotlib.pyplot as plt

# %%
transform = transforms.Compose([transforms.ToTensor(),
                               transforms.Normalize((0.5,), (0.5,))])
teacher_data = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
student_data = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# %%
print("Number of examples in teacher data: " + str(len(teacher_data)))
print("Number of examples in student data: " + str(len(student_data)))
# Out:
# Number of examples in teacher data: 60000
# Number of examples in student data: 10000

# %% [markdown]
# I will divide teacher dataset into 200 different teacher subsets, each subset contains 300 samples.
#
# I will split each subset into 80% train and 20% validation and will train a classifier. There will be 200 classifiers in total.

# %% [markdown]
# ### 2. Train 200 teacher classifiers

# %%
num_teachers, num_examples, num_labels = 200, 300, 10

# %%
# define network architecture

class Teacher(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)
    
    def forward(self, x):
        # flatten input tensor
        x = x.view(x.shape[0], -1)
        
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x

# %%
# initialize 200 teacher classifiers

classifiers = []
for i in range(num_teachers):
    classifiers.append(Teacher())

# %%
# define some hyperparameters
batch_size = 64
epochs = 60
print_every = 5

# %%
# split teacher_data into 200 folds
kf = KFold(n_splits=num_teachers)

for i, (_, data_index) in enumerate(kf.split(teacher_data)):
    # take out one teacher subset
    teacher_subset = Subset(teacher_data, data_index)
    
    classifier = classifiers[i]
    
    print('Training teacher classifier: {}...'.format(i+1))
    
    # split teacher subset into 80% train and 20% test set
    num_samples = len(teacher_subset)
    indices = list(range(num_samples))
    np.random.shuffle(indices)
    split = int(np.floor(0.2 * num_samples))
    train_index, test_index = indices[split:], indices[:split]

    # define samplers for obtaining training and test batches
    train_sampler = SubsetRandomSampler(train_index)
    test_sampler = SubsetRandomSampler(test_index)

    # create dataloader
    trainloader = DataLoader(teacher_subset, batch_size=batch_size, sampler=train_sampler)
    testloader = DataLoader(teacher_subset, batch_size=batch_size, sampler=test_sampler)

    # specify loss and optimization function
    criterion = nn.NLLLoss()
    optimizer = optim.Adam(classifier.parameters(), lr=0.003)

    # training
    classifier.train()

    for epoch in range(epochs):
        train_loss = 0
        for data, label in trainloader:
            optimizer.zero_grad()

            output = classifier(data)
            loss = criterion(output, label)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()*data.size(0)

        if (epoch+1) % print_every == 0:                 
            # switch to validation mode
            classifier.eval()
            test_loss = 0
            accuracy = 0
            with torch.no_grad():
                for data, label in testloader:
                    output = classifier(data)
                    loss = criterion(output, label)
                    test_loss += loss.item()*data.size(0)

                    # calculate accuracy
                    ps = torch.exp(output)
                    top_p, top_class = ps.topk(1, dim=1)
                    equals = top_class == label.view(*top_class.shape)
                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()


                print("Epoch: {}\tTraining loss: {:.4f}\tTest loss: {:.4f}\tTest accuracy: {:.4f}.".format(epoch+1,
                                                                                               train_loss/print_every,
                                                                                               test_loss/len(testloader),
                                                                                               accuracy/len(testloader)))
            # switch back to training mode
            classifier.train()
# Out:
# Training teacher classifier: 1...
# Epoch: 5	Training loss: 47.2853	Test loss: 58.0930	Test accuracy: 0.6167.
# Epoch: 10	Training loss: 15.9196	Test loss: 28.6600	Test accuracy: 0.8833.
# Epoch: 15	Training loss: 4.2542	Test loss: 30.4773	Test accuracy: 0.8833.
# Epoch: 20	Training loss: 0.6943	Test loss: 35.1749	Test accuracy: 0.8667.
# Epoch: 25	Training loss: 0.2245	Test loss: 32.4314	Test accuracy: 0.8667.
# Epoch: 30	Training loss: 0.1129	Test loss: 35.2725	Test accuracy: 0.8667.
# Epoch: 35	Training loss: 0.0824	Test loss: 36.2324	Test accuracy: 0.8833.
# Epoch: 40	Training loss: 0.0634	Test loss: 37.1794	Test accuracy: 0.8667.
# Epoch: 45	Training loss: 0.0516	Test loss: 37.7064	Test accuracy: 0.8667.
# Epoch: 50	Training loss: 0.0430	Test loss: 38.4186	Test accuracy: 0.8667.
# Epoch: 55	Training loss: 0.0360	Test loss: 38.7942	Test accuracy: 0.8667.
# Epoch: 60	Training loss: 0.0310	Test loss: 39.5745	Test accuracy: 0.8667.
# Training teacher classifier: 2...
# Epoch: 5	Training loss: 58.7210	Test loss: 61.1106	Test accuracy: 0.6000.
# Epoch: 10	Training loss: 16.4594	Test loss: 47.3568	Test accuracy: 0.7833.
# Epoch: 15	Training loss: 5.7784	Test loss: 38.5127	Test accuracy: 0.8000.
# Epoch: 20	Training loss: 1.5130	Test loss: 51.8928	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 0.4289	Test loss: 52.6290	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.1898	Test loss: 57.7984	Test accuracy: 0.7833.
# Epoch: 35	Training loss: 0.1276	Test loss: 59.0419	Test accuracy: 0.8000.
# Epoch: 40	Training loss: 0.0967	Test loss: 61.2309	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0776	Test loss: 62.8475	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0633	Test loss: 63.8347	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0529	Test loss: 64.9142	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0451	Test loss: 65.9703	Test accuracy: 0.8333.
# Training teacher classifier: 3...
# Epoch: 5	Training loss: 54.6773	Test loss: 64.4071	Test accuracy: 0.6333.
# Epoch: 10	Training loss: 24.1348	Test loss: 46.5165	Test accuracy: 0.7667.
# Epoch: 15	Training loss: 9.2109	Test loss: 43.7174	Test accuracy: 0.7667.
# Epoch: 20	Training loss: 1.8536	Test loss: 41.2658	Test accuracy: 0.8000.
# Epoch: 25	Training loss: 0.6117	Test loss: 51.1162	Test accuracy: 0.8000.
# Epoch: 30	Training loss: 0.2699	Test loss: 50.9005	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.1740	Test loss: 52.1038	Test accuracy: 0.7833.
# Epoch: 40	Training loss: 0.1298	Test loss: 53.4924	Test accuracy: 0.7833.
# Epoch: 45	Training loss: 0.1010	Test loss: 55.0675	Test accuracy: 0.7833.
# Epoch: 50	Training loss: 0.0814	Test loss: 55.8137	Test accuracy: 0.7833.
# Epoch: 55	Training loss: 0.0672	Test loss: 57.1433	Test accuracy: 0.7833.
# Epoch: 60	Training loss: 0.0566	Test loss: 57.4265	Test accuracy: 0.7833.
# Training teacher classifier: 4...
# Epoch: 5	Training loss: 52.7681	Test loss: 69.1218	Test accuracy: 0.5667.
# Epoch: 10	Training loss: 18.8205	Test loss: 46.7393	Test accuracy: 0.7500.
# Epoch: 15	Training loss: 9.0803	Test loss: 36.2501	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 2.1889	Test loss: 37.1071	Test accuracy: 0.8167.
# Epoch: 25	Training loss: 0.5843	Test loss: 40.4102	Test accuracy: 0.8500.
# Epoch: 30	Training loss: 0.2705	Test loss: 39.2479	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.1529	Test loss: 40.4608	Test accuracy: 0.8500.
# Epoch: 40	Training loss: 0.1095	Test loss: 40.2093	Test accuracy: 0.8667.
# Epoch: 45	Training loss: 0.0867	Test loss: 39.7351	Test accuracy: 0.8500.
# Epoch: 50	Training loss: 0.0708	Test loss: 41.2564	Test accuracy: 0.8500.
# Epoch: 55	Training loss: 0.0582	Test loss: 42.1167	Test accuracy: 0.8500.
# Epoch: 60	Training loss: 0.0483	Test loss: 42.6259	Test accuracy: 0.8500.
# Training teacher classifier: 5...
# Epoch: 5	Training loss: 54.8202	Test loss: 64.7398	Test accuracy: 0.7000.
# Epoch: 10	Training loss: 13.9228	Test loss: 54.2120	Test accuracy: 0.7500.
# Epoch: 15	Training loss: 4.8121	Test loss: 48.9741	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 1.2511	Test loss: 55.2074	Test accuracy: 0.8000.
# Epoch: 25	Training loss: 0.6950	Test loss: 60.3816	Test accuracy: 0.7833.
# Epoch: 30	Training loss: 0.1813	Test loss: 65.0826	Test accuracy: 0.7833.
# Epoch: 35	Training loss: 0.1107	Test loss: 67.8225	Test accuracy: 0.7833.
# Epoch: 40	Training loss: 0.0755	Test loss: 71.2182	Test accuracy: 0.7833.
# Epoch: 45	Training loss: 0.0615	Test loss: 71.8559	Test accuracy: 0.8000.
# Epoch: 50	Training loss: 0.0516	Test loss: 72.7042	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0445	Test loss: 73.5014	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0389	Test loss: 74.3478	Test accuracy: 0.8167.
# Training teacher classifier: 6...
# Epoch: 5	Training loss: 53.8888	Test loss: 89.4998	Test accuracy: 0.5500.
# Epoch: 10	Training loss: 17.6742	Test loss: 50.8302	Test accuracy: 0.7833.
# Epoch: 15	Training loss: 6.1591	Test loss: 62.8795	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 1.9713	Test loss: 55.7946	Test accuracy: 0.8500.
# Epoch: 25	Training loss: 0.5471	Test loss: 58.4017	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.2543	Test loss: 61.0819	Test accuracy: 0.8167.
# Epoch: 35	Training loss: 0.1586	Test loss: 63.9957	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.1169	Test loss: 64.8045	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0911	Test loss: 65.5337	Test accuracy: 0.8000.
# Epoch: 50	Training loss: 0.0747	Test loss: 65.9584	Test accuracy: 0.8000.
# Epoch: 55	Training loss: 0.0618	Test loss: 66.4981	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0523	Test loss: 67.5659	Test accuracy: 0.8000.
# Training teacher classifier: 7...
# Epoch: 5	Training loss: 48.0685	Test loss: 64.5170	Test accuracy: 0.6000.
# Epoch: 10	Training loss: 13.5279	Test loss: 35.4575	Test accuracy: 0.7667.
# Epoch: 15	Training loss: 4.3960	Test loss: 30.6366	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 0.9692	Test loss: 31.9025	Test accuracy: 0.7833.
# Epoch: 25	Training loss: 0.3720	Test loss: 34.7212	Test accuracy: 0.7667.
# Epoch: 30	Training loss: 0.1882	Test loss: 41.4322	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.1338	Test loss: 43.5649	Test accuracy: 0.8000.
# Epoch: 40	Training loss: 0.0968	Test loss: 43.7941	Test accuracy: 0.8000.
# Epoch: 45	Training loss: 0.0784	Test loss: 45.5062	Test accuracy: 0.8000.
# Epoch: 50	Training loss: 0.0637	Test loss: 45.7634	Test accuracy: 0.8000.
# Epoch: 55	Training loss: 0.0529	Test loss: 47.4419	Test accuracy: 0.7833.
# Epoch: 60	Training loss: 0.0449	Test loss: 47.9766	Test accuracy: 0.7833.
# Training teacher classifier: 8...
# Epoch: 5	Training loss: 41.1869	Test loss: 50.0508	Test accuracy: 0.7000.
# Epoch: 10	Training loss: 15.3765	Test loss: 42.9832	Test accuracy: 0.7500.
# Epoch: 15	Training loss: 6.2094	Test loss: 27.6601	Test accuracy: 0.8667.
# Epoch: 20	Training loss: 1.3121	Test loss: 29.4382	Test accuracy: 0.8500.
# Epoch: 25	Training loss: 0.4324	Test loss: 27.3620	Test accuracy: 0.8833.
# Epoch: 30	Training loss: 0.1369	Test loss: 30.6356	Test accuracy: 0.9000.
# Epoch: 35	Training loss: 0.0866	Test loss: 28.9584	Test accuracy: 0.8833.
# Epoch: 40	Training loss: 0.0657	Test loss: 30.1245	Test accuracy: 0.8833.
# Epoch: 45	Training loss: 0.0534	Test loss: 30.1103	Test accuracy: 0.8833.
# Epoch: 50	Training loss: 0.0449	Test loss: 30.6061	Test accuracy: 0.8833.
# Epoch: 55	Training loss: 0.0382	Test loss: 31.1676	Test accuracy: 0.8833.
# Epoch: 60	Training loss: 0.0332	Test loss: 31.4267	Test accuracy: 0.8833.
# Training teacher classifier: 9...
# Epoch: 5	Training loss: 60.9386	Test loss: 80.2621	Test accuracy: 0.5500.
# Epoch: 10	Training loss: 18.8119	Test loss: 40.8016	Test accuracy: 0.8000.
# Epoch: 15	Training loss: 5.6448	Test loss: 37.2754	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 1.8907	Test loss: 44.5843	Test accuracy: 0.7833.
# Epoch: 25	Training loss: 0.5495	Test loss: 43.6801	Test accuracy: 0.8500.
# Epoch: 30	Training loss: 0.2860	Test loss: 51.2890	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.1656	Test loss: 51.2771	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.1211	Test loss: 54.0583	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.0927	Test loss: 54.1265	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0736	Test loss: 55.1451	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0619	Test loss: 57.2372	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0526	Test loss: 58.6165	Test accuracy: 0.8333.
# Training teacher classifier: 10...
# Epoch: 5	Training loss: 43.4973	Test loss: 55.4427	Test accuracy: 0.6667.
# Epoch: 10	Training loss: 15.6168	Test loss: 35.2347	Test accuracy: 0.8167.
# Epoch: 15	Training loss: 4.1507	Test loss: 34.0519	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 0.9239	Test loss: 34.8314	Test accuracy: 0.8667.
# Epoch: 25	Training loss: 0.3308	Test loss: 37.0062	Test accuracy: 0.8833.
# Epoch: 30	Training loss: 0.1754	Test loss: 39.1894	Test accuracy: 0.8667.
# Epoch: 35	Training loss: 0.1167	Test loss: 41.1207	Test accuracy: 0.8500.
# Epoch: 40	Training loss: 0.0868	Test loss: 41.1240	Test accuracy: 0.8667.
# Epoch: 45	Training loss: 0.0685	Test loss: 41.7336	Test accuracy: 0.8667.
# Epoch: 50	Training loss: 0.0562	Test loss: 42.4708	Test accuracy: 0.8667.
# Epoch: 55	Training loss: 0.0469	Test loss: 42.5544	Test accuracy: 0.8667.
# Epoch: 60	Training loss: 0.0397	Test loss: 43.3489	Test accuracy: 0.8667.
# Training teacher classifier: 11...
# Epoch: 5	Training loss: 64.9648	Test loss: 88.2296	Test accuracy: 0.3500.
# Epoch: 10	Training loss: 24.0363	Test loss: 51.3697	Test accuracy: 0.6500.
# Epoch: 15	Training loss: 8.1477	Test loss: 41.2105	Test accuracy: 0.7500.
# Epoch: 20	Training loss: 2.9566	Test loss: 41.7811	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 0.6425	Test loss: 43.0742	Test accuracy: 0.8000.
# Epoch: 30	Training loss: 0.2656	Test loss: 50.0912	Test accuracy: 0.7500.
# Epoch: 35	Training loss: 0.1703	Test loss: 51.6238	Test accuracy: 0.7500.
# Epoch: 40	Training loss: 0.1267	Test loss: 52.2857	Test accuracy: 0.7667.
# Epoch: 45	Training loss: 0.0990	Test loss: 53.4880	Test accuracy: 0.7667.
# Epoch: 50	Training loss: 0.0803	Test loss: 54.3988	Test accuracy: 0.7833.
# Epoch: 55	Training loss: 0.0670	Test loss: 55.2037	Test accuracy: 0.7833.
# Epoch: 60	Training loss: 0.0572	Test loss: 56.4773	Test accuracy: 0.7833.
# Training teacher classifier: 12...
# Epoch: 5	Training loss: 51.4904	Test loss: 57.4594	Test accuracy: 0.6000.
# Epoch: 10	Training loss: 23.8504	Test loss: 31.1149	Test accuracy: 0.7667.
# Epoch: 15	Training loss: 8.6022	Test loss: 25.5032	Test accuracy: 0.8000.
# Epoch: 20	Training loss: 3.2994	Test loss: 23.4985	Test accuracy: 0.8667.
# Epoch: 25	Training loss: 0.5679	Test loss: 20.8306	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.2078	Test loss: 19.4369	Test accuracy: 0.8833.
# Epoch: 35	Training loss: 0.1267	Test loss: 20.2791	Test accuracy: 0.8833.
# Epoch: 40	Training loss: 0.0935	Test loss: 20.1812	Test accuracy: 0.8833.
# Epoch: 45	Training loss: 0.0751	Test loss: 20.6217	Test accuracy: 0.8833.
# Epoch: 50	Training loss: 0.0610	Test loss: 20.2467	Test accuracy: 0.8833.
# Epoch: 55	Training loss: 0.0507	Test loss: 20.2119	Test accuracy: 0.8833.
# Epoch: 60	Training loss: 0.0429	Test loss: 20.3738	Test accuracy: 0.8833.
# Training teacher classifier: 13...
# Epoch: 5	Training loss: 35.9663	Test loss: 64.8406	Test accuracy: 0.6500.
# Epoch: 10	Training loss: 13.3936	Test loss: 53.8238	Test accuracy: 0.7500.
# Epoch: 15	Training loss: 4.7037	Test loss: 44.7033	Test accuracy: 0.8500.
# Epoch: 20	Training loss: 1.4003	Test loss: 52.8096	Test accuracy: 0.8500.
# Epoch: 25	Training loss: 0.6244	Test loss: 58.6624	Test accuracy: 0.8500.
# Epoch: 30	Training loss: 0.2595	Test loss: 56.3375	Test accuracy: 0.8500.
# Epoch: 35	Training loss: 0.1315	Test loss: 62.7460	Test accuracy: 0.8500.
# Epoch: 40	Training loss: 0.0905	Test loss: 65.8198	Test accuracy: 0.8500.
# Epoch: 45	Training loss: 0.0673	Test loss: 67.4785	Test accuracy: 0.8500.
# Epoch: 50	Training loss: 0.0528	Test loss: 67.0645	Test accuracy: 0.8667.
# Epoch: 55	Training loss: 0.0428	Test loss: 68.7040	Test accuracy: 0.8667.
# Epoch: 60	Training loss: 0.0353	Test loss: 69.4047	Test accuracy: 0.8667.
# Training teacher classifier: 14...
# Epoch: 5	Training loss: 51.5631	Test loss: 57.5392	Test accuracy: 0.7500.
# Epoch: 10	Training loss: 21.9889	Test loss: 28.2839	Test accuracy: 0.8000.
# Epoch: 15	Training loss: 7.5597	Test loss: 23.6086	Test accuracy: 0.8833.
# Epoch: 20	Training loss: 2.2305	Test loss: 17.7307	Test accuracy: 0.8667.
# Epoch: 25	Training loss: 0.7943	Test loss: 18.8473	Test accuracy: 0.9167.
# Epoch: 30	Training loss: 0.3658	Test loss: 17.1811	Test accuracy: 0.9167.
# Epoch: 35	Training loss: 0.2204	Test loss: 18.3075	Test accuracy: 0.9333.
# Epoch: 40	Training loss: 0.1419	Test loss: 19.2640	Test accuracy: 0.9000.
# Epoch: 45	Training loss: 0.1102	Test loss: 18.7450	Test accuracy: 0.9333.
# Epoch: 50	Training loss: 0.0885	Test loss: 19.2312	Test accuracy: 0.9333.
# Epoch: 55	Training loss: 0.0741	Test loss: 19.2771	Test accuracy: 0.9167.
# Epoch: 60	Training loss: 0.0631	Test loss: 19.2475	Test accuracy: 0.9333.
# Training teacher classifier: 15...
# Epoch: 5	Training loss: 53.0207	Test loss: 76.2134	Test accuracy: 0.5000.
# Epoch: 10	Training loss: 16.3549	Test loss: 27.5901	Test accuracy: 0.8167.
# Epoch: 15	Training loss: 6.6778	Test loss: 43.2032	Test accuracy: 0.7500.
# Epoch: 20	Training loss: 1.8646	Test loss: 19.7841	Test accuracy: 0.8833.
# Epoch: 25	Training loss: 0.4165	Test loss: 14.1990	Test accuracy: 0.9000.
# Epoch: 30	Training loss: 0.2199	Test loss: 15.4430	Test accuracy: 0.8833.
# Epoch: 35	Training loss: 0.1450	Test loss: 16.7441	Test accuracy: 0.9000.
# Epoch: 40	Training loss: 0.1101	Test loss: 17.1812	Test accuracy: 0.8833.
# Epoch: 45	Training loss: 0.0871	Test loss: 17.2425	Test accuracy: 0.9000.
# Epoch: 50	Training loss: 0.0710	Test loss: 17.4825	Test accuracy: 0.9000.
# Epoch: 55	Training loss: 0.0602	Test loss: 17.5342	Test accuracy: 0.9000.
# Epoch: 60	Training loss: 0.0505	Test loss: 17.6672	Test accuracy: 0.8833.
# Training teacher classifier: 16...
# Epoch: 5	Training loss: 38.2398	Test loss: 49.3319	Test accuracy: 0.7167.
# Epoch: 10	Training loss: 14.5600	Test loss: 30.4259	Test accuracy: 0.8333.
# Epoch: 15	Training loss: 4.6550	Test loss: 22.3675	Test accuracy: 0.8833.
# Epoch: 20	Training loss: 0.9769	Test loss: 25.1085	Test accuracy: 0.9000.
# Epoch: 25	Training loss: 0.2793	Test loss: 23.2843	Test accuracy: 0.9000.
# Epoch: 30	Training loss: 0.1339	Test loss: 24.1133	Test accuracy: 0.9000.
# Epoch: 35	Training loss: 0.0937	Test loss: 25.0837	Test accuracy: 0.8833.
# Epoch: 40	Training loss: 0.0736	Test loss: 25.1082	Test accuracy: 0.8833.
# Epoch: 45	Training loss: 0.0604	Test loss: 25.5509	Test accuracy: 0.8833.
# Epoch: 50	Training loss: 0.0504	Test loss: 26.2438	Test accuracy: 0.8833.
# Epoch: 55	Training loss: 0.0429	Test loss: 26.9718	Test accuracy: 0.8833.
# Epoch: 60	Training loss: 0.0368	Test loss: 27.1773	Test accuracy: 0.8833.
# Training teacher classifier: 17...
# Epoch: 5	Training loss: 44.2983	Test loss: 64.4390	Test accuracy: 0.5833.
# Epoch: 10	Training loss: 14.6105	Test loss: 51.4286	Test accuracy: 0.8500.
# Epoch: 15	Training loss: 3.7907	Test loss: 54.4053	Test accuracy: 0.8000.
# Epoch: 20	Training loss: 1.0255	Test loss: 64.2466	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 0.2865	Test loss: 63.6278	Test accuracy: 0.7833.
# Epoch: 30	Training loss: 0.1241	Test loss: 63.4504	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.0865	Test loss: 65.4627	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.0658	Test loss: 67.1553	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0534	Test loss: 68.0229	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0447	Test loss: 69.2820	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0379	Test loss: 70.1551	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0329	Test loss: 70.8243	Test accuracy: 0.8167.
# Training teacher classifier: 18...
# Epoch: 5	Training loss: 47.4152	Test loss: 76.5370	Test accuracy: 0.5500.
# Epoch: 10	Training loss: 18.6679	Test loss: 67.1678	Test accuracy: 0.6667.
# Epoch: 15	Training loss: 6.1471	Test loss: 76.8293	Test accuracy: 0.7000.
# Epoch: 20	Training loss: 1.0977	Test loss: 99.9714	Test accuracy: 0.7167.
# Epoch: 25	Training loss: 0.2620	Test loss: 105.3388	Test accuracy: 0.7167.
# Epoch: 30	Training loss: 0.1477	Test loss: 104.9458	Test accuracy: 0.7167.
# Epoch: 35	Training loss: 0.0978	Test loss: 108.2142	Test accuracy: 0.7167.
# Epoch: 40	Training loss: 0.0743	Test loss: 111.5991	Test accuracy: 0.7167.
# Epoch: 45	Training loss: 0.0595	Test loss: 113.3754	Test accuracy: 0.7167.
# Epoch: 50	Training loss: 0.0491	Test loss: 115.0436	Test accuracy: 0.7167.
# Epoch: 55	Training loss: 0.0409	Test loss: 116.1809	Test accuracy: 0.7167.
# Epoch: 60	Training loss: 0.0350	Test loss: 117.8119	Test accuracy: 0.7167.
# Training teacher classifier: 19...
# Epoch: 5	Training loss: 47.1480	Test loss: 65.5312	Test accuracy: 0.5833.
# Epoch: 10	Training loss: 12.8832	Test loss: 39.9518	Test accuracy: 0.7500.
# Epoch: 15	Training loss: 4.9980	Test loss: 36.6640	Test accuracy: 0.7667.
# Epoch: 20	Training loss: 2.8523	Test loss: 38.8871	Test accuracy: 0.8000.
# Epoch: 25	Training loss: 0.5723	Test loss: 40.5713	Test accuracy: 0.8000.
# Epoch: 30	Training loss: 0.2152	Test loss: 43.4522	Test accuracy: 0.7833.
# Epoch: 35	Training loss: 0.1189	Test loss: 42.1292	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.0796	Test loss: 42.4149	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0639	Test loss: 42.5726	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0535	Test loss: 43.3965	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0456	Test loss: 44.2432	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0395	Test loss: 45.0868	Test accuracy: 0.8333.
# Training teacher classifier: 20...
# Epoch: 5	Training loss: 57.9360	Test loss: 61.1597	Test accuracy: 0.7000.
# Epoch: 10	Training loss: 22.5616	Test loss: 40.0458	Test accuracy: 0.7833.
# Epoch: 15	Training loss: 5.7751	Test loss: 31.0480	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 1.1579	Test loss: 34.0063	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.3909	Test loss: 41.3185	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.1823	Test loss: 45.4774	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.1205	Test loss: 48.7955	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.0895	Test loss: 52.0018	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0681	Test loss: 53.8224	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0551	Test loss: 56.3434	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0443	Test loss: 58.1542	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0373	Test loss: 59.9672	Test accuracy: 0.8167.
# Training teacher classifier: 21...
# Epoch: 5	Training loss: 45.7825	Test loss: 54.2131	Test accuracy: 0.7167.
# Epoch: 10	Training loss: 5.9773	Test loss: 36.2934	Test accuracy: 0.7833.
# Epoch: 15	Training loss: 0.8878	Test loss: 38.0875	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 0.2486	Test loss: 37.5590	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.1178	Test loss: 41.9014	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.0804	Test loss: 45.3316	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.0612	Test loss: 46.5410	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.0494	Test loss: 48.3679	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.0406	Test loss: 49.8265	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0337	Test loss: 50.9367	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0287	Test loss: 52.4597	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0251	Test loss: 53.3011	Test accuracy: 0.8000.
# Training teacher classifier: 22...
# Epoch: 5	Training loss: 50.9508	Test loss: 60.6390	Test accuracy: 0.7000.
# Epoch: 10	Training loss: 14.7976	Test loss: 41.7956	Test accuracy: 0.8500.
# Epoch: 15	Training loss: 5.4479	Test loss: 49.8709	Test accuracy: 0.8667.
# Epoch: 20	Training loss: 1.2282	Test loss: 42.8833	Test accuracy: 0.8667.
# Epoch: 25	Training loss: 0.3570	Test loss: 45.4268	Test accuracy: 0.8667.
# Epoch: 30	Training loss: 0.1600	Test loss: 46.1195	Test accuracy: 0.8833.
# Epoch: 35	Training loss: 0.1147	Test loss: 45.1664	Test accuracy: 0.8833.
# Epoch: 40	Training loss: 0.0890	Test loss: 46.3646	Test accuracy: 0.8667.
# Epoch: 45	Training loss: 0.0726	Test loss: 47.0973	Test accuracy: 0.8833.
# Epoch: 50	Training loss: 0.0601	Test loss: 47.4575	Test accuracy: 0.8667.
# Epoch: 55	Training loss: 0.0509	Test loss: 48.2542	Test accuracy: 0.8667.
# Epoch: 60	Training loss: 0.0441	Test loss: 48.8745	Test accuracy: 0.8667.
# Training teacher classifier: 23...
# Epoch: 5	Training loss: 49.2706	Test loss: 65.5407	Test accuracy: 0.6833.
# Epoch: 10	Training loss: 17.4129	Test loss: 50.9212	Test accuracy: 0.7833.
# Epoch: 15	Training loss: 4.8447	Test loss: 56.0619	Test accuracy: 0.8000.
# Epoch: 20	Training loss: 0.9637	Test loss: 67.1662	Test accuracy: 0.8000.
# Epoch: 25	Training loss: 0.2700	Test loss: 81.2208	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.1329	Test loss: 81.0352	Test accuracy: 0.8167.
# Epoch: 35	Training loss: 0.0887	Test loss: 85.4612	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.0649	Test loss: 86.6039	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0512	Test loss: 88.8502	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0410	Test loss: 90.0505	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0335	Test loss: 91.4726	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0283	Test loss: 92.7552	Test accuracy: 0.8333.
# Training teacher classifier: 24...
# Epoch: 5	Training loss: 57.2611	Test loss: 78.1545	Test accuracy: 0.4500.
# Epoch: 10	Training loss: 20.9956	Test loss: 50.1577	Test accuracy: 0.7167.
# Epoch: 15	Training loss: 8.6970	Test loss: 56.6089	Test accuracy: 0.6833.
# Epoch: 20	Training loss: 2.6243	Test loss: 46.2725	Test accuracy: 0.7333.
# Epoch: 25	Training loss: 1.2824	Test loss: 53.0541	Test accuracy: 0.7333.
# Epoch: 30	Training loss: 0.5347	Test loss: 60.0855	Test accuracy: 0.7500.
# Epoch: 35	Training loss: 0.1949	Test loss: 63.6181	Test accuracy: 0.7500.
# Epoch: 40	Training loss: 0.1201	Test loss: 65.6406	Test accuracy: 0.7500.
# Epoch: 45	Training loss: 0.0895	Test loss: 67.5352	Test accuracy: 0.7333.
# Epoch: 50	Training loss: 0.0697	Test loss: 68.5573	Test accuracy: 0.7500.
# Epoch: 55	Training loss: 0.0576	Test loss: 70.4100	Test accuracy: 0.7500.
# Epoch: 60	Training loss: 0.0483	Test loss: 71.3705	Test accuracy: 0.7500.
# Training teacher classifier: 25...
# Epoch: 5	Training loss: 72.2307	Test loss: 103.5558	Test accuracy: 0.3333.
# Epoch: 10	Training loss: 31.4954	Test loss: 71.0526	Test accuracy: 0.5833.
# Epoch: 15	Training loss: 12.4884	Test loss: 65.7651	Test accuracy: 0.6667.
# Epoch: 20	Training loss: 5.9781	Test loss: 78.8999	Test accuracy: 0.6333.
# Epoch: 25	Training loss: 2.0224	Test loss: 87.3233	Test accuracy: 0.6667.
# Epoch: 30	Training loss: 0.7384	Test loss: 103.8176	Test accuracy: 0.7167.
# Epoch: 35	Training loss: 0.3429	Test loss: 103.7951	Test accuracy: 0.6833.
# Epoch: 40	Training loss: 0.2111	Test loss: 112.8507	Test accuracy: 0.7000.
# Epoch: 45	Training loss: 0.1496	Test loss: 120.5618	Test accuracy: 0.6833.
# Epoch: 50	Training loss: 0.1089	Test loss: 123.9404	Test accuracy: 0.6833.
# Epoch: 55	Training loss: 0.0868	Test loss: 128.5714	Test accuracy: 0.6833.
# Epoch: 60	Training loss: 0.0701	Test loss: 132.3462	Test accuracy: 0.6833.
# Training teacher classifier: 26...
# Epoch: 5	Training loss: 49.2206	Test loss: 84.4808	Test accuracy: 0.5000.
# Epoch: 10	Training loss: 15.8940	Test loss: 56.6276	Test accuracy: 0.6833.
# Epoch: 15	Training loss: 4.4431	Test loss: 68.6360	Test accuracy: 0.6833.
# Epoch: 20	Training loss: 1.8529	Test loss: 59.5181	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 0.4444	Test loss: 64.2323	Test accuracy: 0.7333.
# Epoch: 30	Training loss: 0.1531	Test loss: 68.1100	Test accuracy: 0.7167.
# Epoch: 35	Training loss: 0.1032	Test loss: 69.7220	Test accuracy: 0.7167.
# Epoch: 40	Training loss: 0.0776	Test loss: 71.2784	Test accuracy: 0.7167.
# Epoch: 45	Training loss: 0.0624	Test loss: 73.3711	Test accuracy: 0.7167.
# Epoch: 50	Training loss: 0.0514	Test loss: 75.0943	Test accuracy: 0.7333.
# Epoch: 55	Training loss: 0.0427	Test loss: 75.4478	Test accuracy: 0.7333.
# Epoch: 60	Training loss: 0.0364	Test loss: 77.1079	Test accuracy: 0.7333.
# Training teacher classifier: 27...
# Epoch: 5	Training loss: 44.5316	Test loss: 71.5407	Test accuracy: 0.5333.
# Epoch: 10	Training loss: 15.6138	Test loss: 37.4670	Test accuracy: 0.7833.
# Epoch: 15	Training loss: 4.9960	Test loss: 43.6046	Test accuracy: 0.8000.
# Epoch: 20	Training loss: 1.2283	Test loss: 49.7462	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.3246	Test loss: 51.7489	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.1594	Test loss: 55.8474	Test accuracy: 0.8500.
# Epoch: 35	Training loss: 0.1085	Test loss: 58.3960	Test accuracy: 0.8500.
# Epoch: 40	Training loss: 0.0824	Test loss: 60.2449	Test accuracy: 0.8500.
# Epoch: 45	Training loss: 0.0661	Test loss: 61.8075	Test accuracy: 0.8500.
# Epoch: 50	Training loss: 0.0543	Test loss: 63.1730	Test accuracy: 0.8500.
# Epoch: 55	Training loss: 0.0454	Test loss: 64.5659	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0388	Test loss: 65.7099	Test accuracy: 0.8333.
# Training teacher classifier: 28...
# Epoch: 5	Training loss: 66.8051	Test loss: 78.2363	Test accuracy: 0.5500.
# Epoch: 10	Training loss: 34.7142	Test loss: 52.8514	Test accuracy: 0.7500.
# Epoch: 15	Training loss: 17.3533	Test loss: 48.7721	Test accuracy: 0.7167.
# Epoch: 20	Training loss: 7.3628	Test loss: 50.8522	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 2.1520	Test loss: 55.3835	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.6731	Test loss: 63.1358	Test accuracy: 0.8167.
# Epoch: 35	Training loss: 0.3394	Test loss: 69.2426	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.2085	Test loss: 72.7548	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.1484	Test loss: 75.6945	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.1134	Test loss: 78.0088	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0905	Test loss: 80.1011	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0748	Test loss: 81.8983	Test accuracy: 0.8333.
# Training teacher classifier: 29...
# Epoch: 5	Training loss: 57.3678	Test loss: 80.0502	Test accuracy: 0.5500.
# Epoch: 10	Training loss: 22.4015	Test loss: 52.5095	Test accuracy: 0.7333.
# Epoch: 15	Training loss: 7.0153	Test loss: 72.3635	Test accuracy: 0.6833.
# Epoch: 20	Training loss: 1.4351	Test loss: 77.4704	Test accuracy: 0.7333.
# Epoch: 25	Training loss: 0.3008	Test loss: 89.4851	Test accuracy: 0.7000.
# Epoch: 30	Training loss: 0.1522	Test loss: 99.0910	Test accuracy: 0.7000.
# Epoch: 35	Training loss: 0.1032	Test loss: 101.5477	Test accuracy: 0.7167.
# Epoch: 40	Training loss: 0.0808	Test loss: 104.4327	Test accuracy: 0.7167.
# Epoch: 45	Training loss: 0.0648	Test loss: 107.3141	Test accuracy: 0.7167.
# Epoch: 50	Training loss: 0.0533	Test loss: 108.9520	Test accuracy: 0.7167.
# Epoch: 55	Training loss: 0.0450	Test loss: 111.3537	Test accuracy: 0.7167.
# Epoch: 60	Training loss: 0.0385	Test loss: 113.0192	Test accuracy: 0.7167.
# Training teacher classifier: 30...
# Epoch: 5	Training loss: 53.5644	Test loss: 66.8272	Test accuracy: 0.6333.
# Epoch: 10	Training loss: 18.1017	Test loss: 57.9615	Test accuracy: 0.7167.
# Epoch: 15	Training loss: 9.2268	Test loss: 55.4092	Test accuracy: 0.7833.
# Epoch: 20	Training loss: 3.8436	Test loss: 68.8045	Test accuracy: 0.7500.
# Epoch: 25	Training loss: 1.6646	Test loss: 56.1553	Test accuracy: 0.8000.
# Epoch: 30	Training loss: 0.4719	Test loss: 62.1907	Test accuracy: 0.8167.
# Epoch: 35	Training loss: 0.1631	Test loss: 66.2705	Test accuracy: 0.7833.
# Epoch: 40	Training loss: 0.0898	Test loss: 72.5825	Test accuracy: 0.7833.
# Epoch: 45	Training loss: 0.0672	Test loss: 72.7747	Test accuracy: 0.8000.
# Epoch: 50	Training loss: 0.0558	Test loss: 74.7174	Test accuracy: 0.8000.
# Epoch: 55	Training loss: 0.0477	Test loss: 75.7316	Test accuracy: 0.8000.
# Epoch: 60	Training loss: 0.0415	Test loss: 76.6326	Test accuracy: 0.8000.
# Training teacher classifier: 31...
# Epoch: 5	Training loss: 50.7745	Test loss: 50.5272	Test accuracy: 0.7333.
# Epoch: 10	Training loss: 16.6127	Test loss: 31.7076	Test accuracy: 0.8000.
# Epoch: 15	Training loss: 6.5610	Test loss: 34.9692	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 1.8531	Test loss: 29.4370	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.5359	Test loss: 28.6605	Test accuracy: 0.8500.
# Epoch: 30	Training loss: 0.2076	Test loss: 30.6500	Test accuracy: 0.8667.
# Epoch: 35	Training loss: 0.1384	Test loss: 29.6935	Test accuracy: 0.8500.
# Epoch: 40	Training loss: 0.1037	Test loss: 31.1420	Test accuracy: 0.8500.
# Epoch: 45	Training loss: 0.0824	Test loss: 31.6328	Test accuracy: 0.8500.
# Epoch: 50	Training loss: 0.0684	Test loss: 31.6879	Test accuracy: 0.8500.
# Epoch: 55	Training loss: 0.0576	Test loss: 31.9661	Test accuracy: 0.8500.
# Epoch: 60	Training loss: 0.0485	Test loss: 32.4516	Test accuracy: 0.8500.
# Training teacher classifier: 32...
# Epoch: 5	Training loss: 44.9440	Test loss: 62.8340	Test accuracy: 0.6500.
# Epoch: 10	Training loss: 14.2273	Test loss: 49.1084	Test accuracy: 0.7667.
# Epoch: 15	Training loss: 3.1814	Test loss: 48.6271	Test accuracy: 0.7667.
# Epoch: 20	Training loss: 0.6276	Test loss: 47.6504	Test accuracy: 0.7833.
# Epoch: 25	Training loss: 0.2463	Test loss: 49.8895	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.1412	Test loss: 50.1747	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.1052	Test loss: 49.8697	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.0806	Test loss: 51.1325	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.0657	Test loss: 51.8057	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0541	Test loss: 52.8105	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0456	Test loss: 53.3361	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0390	Test loss: 54.0985	Test accuracy: 0.8333.
# Training teacher classifier: 33...
# Epoch: 5	Training loss: 37.6198	Test loss: 77.6553	Test accuracy: 0.5333.
# Epoch: 10	Training loss: 13.1753	Test loss: 65.2390	Test accuracy: 0.7667.
# Epoch: 15	Training loss: 2.0410	Test loss: 70.0197	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 0.4870	Test loss: 78.9075	Test accuracy: 0.8500.
# Epoch: 25	Training loss: 0.1964	Test loss: 80.5606	Test accuracy: 0.8500.
# Epoch: 30	Training loss: 0.1200	Test loss: 82.5414	Test accuracy: 0.8500.
# Epoch: 35	Training loss: 0.0912	Test loss: 83.7001	Test accuracy: 0.8500.
# Epoch: 40	Training loss: 0.0715	Test loss: 85.2479	Test accuracy: 0.8500.
# Epoch: 45	Training loss: 0.0581	Test loss: 86.8340	Test accuracy: 0.8500.
# Epoch: 50	Training loss: 0.0482	Test loss: 88.5508	Test accuracy: 0.8500.
# Epoch: 55	Training loss: 0.0411	Test loss: 89.9493	Test accuracy: 0.8500.
# Epoch: 60	Training loss: 0.0351	Test loss: 90.7062	Test accuracy: 0.8500.
# Training teacher classifier: 34...
# Epoch: 5	Training loss: 45.9518	Test loss: 60.7839	Test accuracy: 0.6667.
# Epoch: 10	Training loss: 17.1256	Test loss: 49.2304	Test accuracy: 0.8000.
# Epoch: 15	Training loss: 2.8536	Test loss: 58.3373	Test accuracy: 0.7833.
# Epoch: 20	Training loss: 0.8876	Test loss: 72.3207	Test accuracy: 0.7833.
# Epoch: 25	Training loss: 0.2204	Test loss: 73.7560	Test accuracy: 0.8000.
# Epoch: 30	Training loss: 0.1197	Test loss: 76.3119	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.0875	Test loss: 79.8044	Test accuracy: 0.8000.
# Epoch: 40	Training loss: 0.0690	Test loss: 81.1864	Test accuracy: 0.8000.
# Epoch: 45	Training loss: 0.0567	Test loss: 82.8245	Test accuracy: 0.8000.
# Epoch: 50	Training loss: 0.0474	Test loss: 84.6622	Test accuracy: 0.8000.
# Epoch: 55	Training loss: 0.0404	Test loss: 85.7630	Test accuracy: 0.8000.
# Epoch: 60	Training loss: 0.0347	Test loss: 87.1767	Test accuracy: 0.8000.
# Training teacher classifier: 35...
# Epoch: 5	Training loss: 47.6409	Test loss: 58.5282	Test accuracy: 0.6833.
# Epoch: 10	Training loss: 15.3662	Test loss: 36.9735	Test accuracy: 0.7833.
# Epoch: 15	Training loss: 3.7045	Test loss: 32.2672	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 0.9221	Test loss: 37.5055	Test accuracy: 0.8000.
# Epoch: 25	Training loss: 0.3492	Test loss: 37.9970	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.1477	Test loss: 37.1070	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.0909	Test loss: 37.7664	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.0694	Test loss: 38.3372	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.0559	Test loss: 38.9095	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0466	Test loss: 39.4457	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0394	Test loss: 39.9370	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0339	Test loss: 40.4268	Test accuracy: 0.8333.
# Training teacher classifier: 36...
# Epoch: 5	Training loss: 45.8970	Test loss: 68.1219	Test accuracy: 0.4500.
# Epoch: 10	Training loss: 16.5250	Test loss: 70.4250	Test accuracy: 0.6333.
# Epoch: 15	Training loss: 4.7705	Test loss: 53.6328	Test accuracy: 0.7833.
# Epoch: 20	Training loss: 1.4347	Test loss: 61.9886	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 0.5629	Test loss: 64.7530	Test accuracy: 0.7833.
# Epoch: 30	Training loss: 0.1768	Test loss: 60.8020	Test accuracy: 0.8167.
# Epoch: 35	Training loss: 0.1035	Test loss: 64.3939	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.0710	Test loss: 65.9240	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0529	Test loss: 68.4537	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0423	Test loss: 70.2072	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0341	Test loss: 71.6844	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0285	Test loss: 73.3422	Test accuracy: 0.8167.
# Training teacher classifier: 37...
# Epoch: 5	Training loss: 42.5016	Test loss: 50.7167	Test accuracy: 0.6167.
# Epoch: 10	Training loss: 12.9641	Test loss: 24.6337	Test accuracy: 0.8333.
# Epoch: 15	Training loss: 2.7327	Test loss: 19.8520	Test accuracy: 0.8833.
# Epoch: 20	Training loss: 0.4714	Test loss: 18.2221	Test accuracy: 0.9167.
# Epoch: 25	Training loss: 0.1721	Test loss: 18.6386	Test accuracy: 0.9167.
# Epoch: 30	Training loss: 0.1074	Test loss: 19.0191	Test accuracy: 0.9000.
# Epoch: 35	Training loss: 0.0796	Test loss: 19.0738	Test accuracy: 0.9000.
# Epoch: 40	Training loss: 0.0620	Test loss: 19.5027	Test accuracy: 0.9000.
# Epoch: 45	Training loss: 0.0502	Test loss: 20.3593	Test accuracy: 0.9000.
# Epoch: 50	Training loss: 0.0415	Test loss: 20.8454	Test accuracy: 0.9000.
# Epoch: 55	Training loss: 0.0348	Test loss: 21.0098	Test accuracy: 0.9000.
# Epoch: 60	Training loss: 0.0300	Test loss: 21.0490	Test accuracy: 0.8833.
# Training teacher classifier: 38...
# Epoch: 5	Training loss: 42.7189	Test loss: 63.2242	Test accuracy: 0.6333.
# Epoch: 10	Training loss: 11.5361	Test loss: 43.9735	Test accuracy: 0.7500.
# Epoch: 15	Training loss: 2.9324	Test loss: 31.9267	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 0.6108	Test loss: 48.8354	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 0.1311	Test loss: 43.7671	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.0749	Test loss: 40.4560	Test accuracy: 0.7833.
# Epoch: 35	Training loss: 0.0553	Test loss: 42.5149	Test accuracy: 0.7667.
# Epoch: 40	Training loss: 0.0448	Test loss: 42.7314	Test accuracy: 0.7833.
# Epoch: 45	Training loss: 0.0376	Test loss: 43.3478	Test accuracy: 0.7833.
# Epoch: 50	Training loss: 0.0323	Test loss: 43.8472	Test accuracy: 0.7833.
# Epoch: 55	Training loss: 0.0282	Test loss: 44.6609	Test accuracy: 0.7833.
# Epoch: 60	Training loss: 0.0247	Test loss: 44.7579	Test accuracy: 0.7833.
# Training teacher classifier: 39...
# Epoch: 5	Training loss: 53.9672	Test loss: 66.6170	Test accuracy: 0.6833.
# Epoch: 10	Training loss: 22.6363	Test loss: 64.2184	Test accuracy: 0.6833.
# Epoch: 15	Training loss: 7.1570	Test loss: 51.7266	Test accuracy: 0.7667.
# Epoch: 20	Training loss: 2.2880	Test loss: 53.0606	Test accuracy: 0.8000.
# Epoch: 25	Training loss: 0.6827	Test loss: 66.0069	Test accuracy: 0.7833.
# Epoch: 30	Training loss: 0.2606	Test loss: 71.6236	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.1697	Test loss: 76.6180	Test accuracy: 0.8000.
# Epoch: 40	Training loss: 0.1249	Test loss: 77.8950	Test accuracy: 0.8000.
# Epoch: 45	Training loss: 0.0993	Test loss: 79.6774	Test accuracy: 0.8000.
# Epoch: 50	Training loss: 0.0812	Test loss: 81.5160	Test accuracy: 0.8000.
# Epoch: 55	Training loss: 0.0679	Test loss: 82.7308	Test accuracy: 0.8000.
# Epoch: 60	Training loss: 0.0580	Test loss: 84.3864	Test accuracy: 0.8000.
# Training teacher classifier: 40...
# Epoch: 5	Training loss: 58.4209	Test loss: 76.1970	Test accuracy: 0.5667.
# Epoch: 10	Training loss: 22.0497	Test loss: 46.1545	Test accuracy: 0.8000.
# Epoch: 15	Training loss: 7.0512	Test loss: 37.6389	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 2.3141	Test loss: 45.1592	Test accuracy: 0.8167.
# Epoch: 25	Training loss: 0.7164	Test loss: 51.0859	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.4638	Test loss: 52.0367	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.1547	Test loss: 52.3867	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.0981	Test loss: 52.3275	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.0763	Test loss: 52.9628	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0624	Test loss: 53.7172	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0524	Test loss: 54.6028	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0444	Test loss: 55.6545	Test accuracy: 0.8333.
# Training teacher classifier: 41...
# Epoch: 5	Training loss: 52.6570	Test loss: 66.3856	Test accuracy: 0.6333.
# Epoch: 10	Training loss: 15.9654	Test loss: 45.0198	Test accuracy: 0.7333.
# Epoch: 15	Training loss: 5.1212	Test loss: 38.1399	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 1.6005	Test loss: 41.8884	Test accuracy: 0.8167.
# Epoch: 25	Training loss: 0.6971	Test loss: 46.6173	Test accuracy: 0.8500.
# Epoch: 30	Training loss: 0.2151	Test loss: 41.5798	Test accuracy: 0.8667.
# Epoch: 35	Training loss: 0.1173	Test loss: 41.0665	Test accuracy: 0.8667.
# Epoch: 40	Training loss: 0.0838	Test loss: 41.7834	Test accuracy: 0.8667.
# Epoch: 45	Training loss: 0.0669	Test loss: 42.3917	Test accuracy: 0.8667.
# Epoch: 50	Training loss: 0.0551	Test loss: 42.8946	Test accuracy: 0.8667.
# Epoch: 55	Training loss: 0.0466	Test loss: 43.2584	Test accuracy: 0.8667.
# Epoch: 60	Training loss: 0.0398	Test loss: 43.9003	Test accuracy: 0.8667.
# Training teacher classifier: 42...
# Epoch: 5	Training loss: 58.6325	Test loss: 63.8566	Test accuracy: 0.6500.
# Epoch: 10	Training loss: 20.1728	Test loss: 44.2818	Test accuracy: 0.7667.
# Epoch: 15	Training loss: 9.0057	Test loss: 34.2861	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 2.3553	Test loss: 41.7919	Test accuracy: 0.8000.
# Epoch: 25	Training loss: 0.6224	Test loss: 40.7677	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.2466	Test loss: 42.5773	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.1530	Test loss: 41.9616	Test accuracy: 0.8000.
# Epoch: 40	Training loss: 0.1123	Test loss: 44.6671	Test accuracy: 0.8000.
# Epoch: 45	Training loss: 0.0873	Test loss: 45.4097	Test accuracy: 0.8000.
# Epoch: 50	Training loss: 0.0715	Test loss: 46.7134	Test accuracy: 0.8000.
# Epoch: 55	Training loss: 0.0586	Test loss: 47.9091	Test accuracy: 0.8000.
# Epoch: 60	Training loss: 0.0490	Test loss: 49.3286	Test accuracy: 0.8000.
# Training teacher classifier: 43...
# Epoch: 5	Training loss: 47.9828	Test loss: 49.9098	Test accuracy: 0.7833.
# Epoch: 10	Training loss: 22.8237	Test loss: 34.3681	Test accuracy: 0.8667.
# Epoch: 15	Training loss: 6.6490	Test loss: 33.2490	Test accuracy: 0.8500.
# Epoch: 20	Training loss: 1.7107	Test loss: 39.1037	Test accuracy: 0.8500.
# Epoch: 25	Training loss: 0.4814	Test loss: 40.8874	Test accuracy: 0.8833.
# Epoch: 30	Training loss: 0.2438	Test loss: 43.9925	Test accuracy: 0.8500.
# Epoch: 35	Training loss: 0.1651	Test loss: 45.1447	Test accuracy: 0.8667.
# Epoch: 40	Training loss: 0.1231	Test loss: 46.7516	Test accuracy: 0.8667.
# Epoch: 45	Training loss: 0.0976	Test loss: 48.3002	Test accuracy: 0.8833.
# Epoch: 50	Training loss: 0.0788	Test loss: 48.8758	Test accuracy: 0.8667.
# Epoch: 55	Training loss: 0.0652	Test loss: 49.8475	Test accuracy: 0.8667.
# Epoch: 60	Training loss: 0.0549	Test loss: 50.7031	Test accuracy: 0.8667.
# Training teacher classifier: 44...
# Epoch: 5	Training loss: 38.4554	Test loss: 70.3990	Test accuracy: 0.6000.
# Epoch: 10	Training loss: 14.3268	Test loss: 81.2765	Test accuracy: 0.7000.
# Epoch: 15	Training loss: 3.2609	Test loss: 86.0342	Test accuracy: 0.6833.
# Epoch: 20	Training loss: 0.7586	Test loss: 106.6039	Test accuracy: 0.7000.
# Epoch: 25	Training loss: 0.2668	Test loss: 113.8552	Test accuracy: 0.7000.
# Epoch: 30	Training loss: 0.1318	Test loss: 122.0999	Test accuracy: 0.7000.
# Epoch: 35	Training loss: 0.0956	Test loss: 125.8900	Test accuracy: 0.7000.
# Epoch: 40	Training loss: 0.0741	Test loss: 129.5957	Test accuracy: 0.7000.
# Epoch: 45	Training loss: 0.0607	Test loss: 132.6343	Test accuracy: 0.7000.
# Epoch: 50	Training loss: 0.0510	Test loss: 135.3953	Test accuracy: 0.7000.
# Epoch: 55	Training loss: 0.0432	Test loss: 137.9518	Test accuracy: 0.7000.
# Epoch: 60	Training loss: 0.0373	Test loss: 139.6425	Test accuracy: 0.7000.
# Training teacher classifier: 45...
# Epoch: 5	Training loss: 45.6752	Test loss: 52.6838	Test accuracy: 0.7167.
# Epoch: 10	Training loss: 12.5698	Test loss: 44.1093	Test accuracy: 0.7667.
# Epoch: 15	Training loss: 3.0684	Test loss: 68.1223	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 1.0193	Test loss: 62.2155	Test accuracy: 0.8000.
# Epoch: 25	Training loss: 0.3045	Test loss: 62.6473	Test accuracy: 0.8000.
# Epoch: 30	Training loss: 0.1598	Test loss: 65.4927	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.1123	Test loss: 68.1829	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.0884	Test loss: 69.6628	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0721	Test loss: 70.6685	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0599	Test loss: 71.8124	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0508	Test loss: 72.5844	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0435	Test loss: 72.7354	Test accuracy: 0.8167.
# Training teacher classifier: 46...
# Epoch: 5	Training loss: 61.5152	Test loss: 68.0752	Test accuracy: 0.6500.
# Epoch: 10	Training loss: 21.5414	Test loss: 31.3052	Test accuracy: 0.8333.
# Epoch: 15	Training loss: 6.5397	Test loss: 23.7054	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 2.7530	Test loss: 16.8744	Test accuracy: 0.9000.
# Epoch: 25	Training loss: 0.4818	Test loss: 21.8899	Test accuracy: 0.8833.
# Epoch: 30	Training loss: 0.2121	Test loss: 23.7935	Test accuracy: 0.9000.
# Epoch: 35	Training loss: 0.1358	Test loss: 23.8779	Test accuracy: 0.9000.
# Epoch: 40	Training loss: 0.1009	Test loss: 24.3021	Test accuracy: 0.9000.
# Epoch: 45	Training loss: 0.0809	Test loss: 25.0045	Test accuracy: 0.9000.
# Epoch: 50	Training loss: 0.0662	Test loss: 24.7894	Test accuracy: 0.9000.
# Epoch: 55	Training loss: 0.0555	Test loss: 25.2056	Test accuracy: 0.9000.
# Epoch: 60	Training loss: 0.0474	Test loss: 25.5608	Test accuracy: 0.9000.
# Training teacher classifier: 47...
# Epoch: 5	Training loss: 57.9534	Test loss: 70.7416	Test accuracy: 0.5167.
# Epoch: 10	Training loss: 22.0196	Test loss: 59.5209	Test accuracy: 0.7500.
# Epoch: 15	Training loss: 7.7274	Test loss: 78.0488	Test accuracy: 0.7500.
# Epoch: 20	Training loss: 4.0629	Test loss: 92.1191	Test accuracy: 0.7833.
# Epoch: 25	Training loss: 0.9782	Test loss: 98.6322	Test accuracy: 0.7500.
# Epoch: 30	Training loss: 0.2857	Test loss: 107.9409	Test accuracy: 0.7667.
# Epoch: 35	Training loss: 0.1616	Test loss: 115.2162	Test accuracy: 0.7667.
# Epoch: 40	Training loss: 0.1163	Test loss: 119.9363	Test accuracy: 0.7667.
# Epoch: 45	Training loss: 0.0887	Test loss: 123.3616	Test accuracy: 0.7500.
# Epoch: 50	Training loss: 0.0707	Test loss: 126.0801	Test accuracy: 0.7667.
# Epoch: 55	Training loss: 0.0584	Test loss: 129.3646	Test accuracy: 0.7667.
# Epoch: 60	Training loss: 0.0494	Test loss: 131.2139	Test accuracy: 0.7667.
# Training teacher classifier: 48...
# Epoch: 5	Training loss: 62.2260	Test loss: 71.0323	Test accuracy: 0.6000.
# Epoch: 10	Training loss: 24.8313	Test loss: 55.6657	Test accuracy: 0.7167.
# Epoch: 15	Training loss: 10.1718	Test loss: 42.9306	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 3.4250	Test loss: 45.5222	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 0.9255	Test loss: 52.2444	Test accuracy: 0.8000.
# Epoch: 30	Training loss: 0.4102	Test loss: 51.0691	Test accuracy: 0.7833.
# Epoch: 35	Training loss: 0.1802	Test loss: 50.3687	Test accuracy: 0.8000.
# Epoch: 40	Training loss: 0.1270	Test loss: 53.7391	Test accuracy: 0.7833.
# Epoch: 45	Training loss: 0.1004	Test loss: 55.6582	Test accuracy: 0.7833.
# Epoch: 50	Training loss: 0.0815	Test loss: 56.6729	Test accuracy: 0.7833.
# Epoch: 55	Training loss: 0.0687	Test loss: 56.6148	Test accuracy: 0.7833.
# Epoch: 60	Training loss: 0.0579	Test loss: 57.8584	Test accuracy: 0.7833.
# Training teacher classifier: 49...
# Epoch: 5	Training loss: 57.7734	Test loss: 75.4443	Test accuracy: 0.5667.
# Epoch: 10	Training loss: 17.7976	Test loss: 54.3304	Test accuracy: 0.6833.
# Epoch: 15	Training loss: 3.1043	Test loss: 54.9986	Test accuracy: 0.7500.
# Epoch: 20	Training loss: 0.6631	Test loss: 56.1082	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 0.2169	Test loss: 58.0201	Test accuracy: 0.7833.
# Epoch: 30	Training loss: 0.1268	Test loss: 60.0487	Test accuracy: 0.7833.
# Epoch: 35	Training loss: 0.0920	Test loss: 61.9288	Test accuracy: 0.7667.
# Epoch: 40	Training loss: 0.0717	Test loss: 62.9789	Test accuracy: 0.7667.
# Epoch: 45	Training loss: 0.0583	Test loss: 64.0282	Test accuracy: 0.7667.
# Epoch: 50	Training loss: 0.0479	Test loss: 65.1108	Test accuracy: 0.7667.
# Epoch: 55	Training loss: 0.0404	Test loss: 65.8953	Test accuracy: 0.7667.
# Epoch: 60	Training loss: 0.0349	Test loss: 66.6426	Test accuracy: 0.7667.
# Training teacher classifier: 50...
# Epoch: 5	Training loss: 55.2160	Test loss: 61.6720	Test accuracy: 0.7500.
# Epoch: 10	Training loss: 20.8293	Test loss: 63.7893	Test accuracy: 0.7000.
# Epoch: 15	Training loss: 8.2740	Test loss: 49.9330	Test accuracy: 0.8500.
# Epoch: 20	Training loss: 2.4883	Test loss: 51.1473	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.8865	Test loss: 58.8339	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.3184	Test loss: 60.9011	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.1966	Test loss: 62.6106	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.1283	Test loss: 65.9344	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.1011	Test loss: 68.1185	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0829	Test loss: 69.1252	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0684	Test loss: 70.6174	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0583	Test loss: 72.1748	Test accuracy: 0.8333.
# Training teacher classifier: 51...
# Epoch: 5	Training loss: 42.5564	Test loss: 66.5972	Test accuracy: 0.7000.
# Epoch: 10	Training loss: 14.2620	Test loss: 54.9024	Test accuracy: 0.7333.
# Epoch: 15	Training loss: 4.8961	Test loss: 54.2791	Test accuracy: 0.8000.
# Epoch: 20	Training loss: 0.8022	Test loss: 55.1665	Test accuracy: 0.7667.
# Epoch: 25	Training loss: 0.2255	Test loss: 62.0587	Test accuracy: 0.7667.
# Epoch: 30	Training loss: 0.1263	Test loss: 66.4565	Test accuracy: 0.7833.
# Epoch: 35	Training loss: 0.0826	Test loss: 65.3200	Test accuracy: 0.7833.
# Epoch: 40	Training loss: 0.0619	Test loss: 67.5849	Test accuracy: 0.7833.
# Epoch: 45	Training loss: 0.0493	Test loss: 69.2956	Test accuracy: 0.7833.
# Epoch: 50	Training loss: 0.0400	Test loss: 71.2785	Test accuracy: 0.7833.
# Epoch: 55	Training loss: 0.0332	Test loss: 72.4494	Test accuracy: 0.7833.
# Epoch: 60	Training loss: 0.0284	Test loss: 73.2161	Test accuracy: 0.7833.
# Training teacher classifier: 52...
# Epoch: 5	Training loss: 57.1158	Test loss: 61.9929	Test accuracy: 0.7000.
# Epoch: 10	Training loss: 19.4125	Test loss: 41.7597	Test accuracy: 0.8667.
# Epoch: 15	Training loss: 5.6717	Test loss: 42.4626	Test accuracy: 0.7833.
# Epoch: 20	Training loss: 2.5238	Test loss: 43.1301	Test accuracy: 0.8167.
# Epoch: 25	Training loss: 0.7704	Test loss: 51.1190	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.2916	Test loss: 53.0685	Test accuracy: 0.8167.
# Epoch: 35	Training loss: 0.1873	Test loss: 51.9976	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.1175	Test loss: 53.7102	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.0913	Test loss: 54.6597	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0739	Test loss: 55.3296	Test accuracy: 0.8333.
# ...
# Epoch: 50	Training loss: 0.0588	Test loss: 57.1847	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0497	Test loss: 57.8072	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0428	Test loss: 58.7095	Test accuracy: 0.8333.
# Training teacher classifier: 184...
# Epoch: 5	Training loss: 55.5107	Test loss: 61.4003	Test accuracy: 0.7167.
# Epoch: 10	Training loss: 23.3298	Test loss: 42.3079	Test accuracy: 0.7667.
# Epoch: 15	Training loss: 6.0832	Test loss: 43.8873	Test accuracy: 0.8500.
# Epoch: 20	Training loss: 2.0815	Test loss: 52.6164	Test accuracy: 0.7833.
# Epoch: 25	Training loss: 0.5508	Test loss: 58.6256	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.2087	Test loss: 60.5255	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.1228	Test loss: 61.4921	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.0928	Test loss: 63.5485	Test accuracy: 0.8667.
# Epoch: 45	Training loss: 0.0748	Test loss: 64.9657	Test accuracy: 0.8500.
# Epoch: 50	Training loss: 0.0617	Test loss: 66.0692	Test accuracy: 0.8500.
# Epoch: 55	Training loss: 0.0529	Test loss: 67.2343	Test accuracy: 0.8500.
# Epoch: 60	Training loss: 0.0450	Test loss: 68.0890	Test accuracy: 0.8500.
# Training teacher classifier: 185...
# Epoch: 5	Training loss: 53.9898	Test loss: 59.7215	Test accuracy: 0.7167.
# Epoch: 10	Training loss: 14.8679	Test loss: 57.9241	Test accuracy: 0.7500.
# Epoch: 15	Training loss: 7.0363	Test loss: 44.9509	Test accuracy: 0.7667.
# Epoch: 20	Training loss: 1.8062	Test loss: 33.2248	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.4232	Test loss: 33.1453	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.1875	Test loss: 35.3788	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.1216	Test loss: 34.4451	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.0931	Test loss: 35.6629	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0747	Test loss: 36.2871	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0605	Test loss: 38.0028	Test accuracy: 0.8000.
# Epoch: 55	Training loss: 0.0508	Test loss: 38.6664	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0439	Test loss: 39.4395	Test accuracy: 0.8000.
# Training teacher classifier: 186...
# Epoch: 5	Training loss: 37.1653	Test loss: 47.1226	Test accuracy: 0.7167.
# Epoch: 10	Training loss: 14.0734	Test loss: 51.2156	Test accuracy: 0.7667.
# Epoch: 15	Training loss: 4.8657	Test loss: 36.9617	Test accuracy: 0.8000.
# Epoch: 20	Training loss: 1.0352	Test loss: 27.5735	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.3944	Test loss: 30.3553	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.1903	Test loss: 32.8526	Test accuracy: 0.8167.
# Epoch: 35	Training loss: 0.1247	Test loss: 32.6044	Test accuracy: 0.8167.
# Epoch: 40	Training loss: 0.0898	Test loss: 35.2933	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0687	Test loss: 38.2001	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0527	Test loss: 40.2089	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0423	Test loss: 41.2772	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0347	Test loss: 42.2568	Test accuracy: 0.8167.
# Training teacher classifier: 187...
# Epoch: 5	Training loss: 44.8586	Test loss: 62.1226	Test accuracy: 0.6000.
# Epoch: 10	Training loss: 14.4708	Test loss: 23.4992	Test accuracy: 0.7833.
# Epoch: 15	Training loss: 6.9839	Test loss: 27.5728	Test accuracy: 0.8667.
# Epoch: 20	Training loss: 2.0225	Test loss: 24.0339	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.5866	Test loss: 20.0119	Test accuracy: 0.8833.
# Epoch: 30	Training loss: 0.2557	Test loss: 19.1905	Test accuracy: 0.9000.
# Epoch: 35	Training loss: 0.1531	Test loss: 18.1518	Test accuracy: 0.9167.
# Epoch: 40	Training loss: 0.1116	Test loss: 18.6194	Test accuracy: 0.9167.
# Epoch: 45	Training loss: 0.0855	Test loss: 18.3742	Test accuracy: 0.9500.
# Epoch: 50	Training loss: 0.0683	Test loss: 18.7064	Test accuracy: 0.9500.
# Epoch: 55	Training loss: 0.0555	Test loss: 19.0746	Test accuracy: 0.9333.
# Epoch: 60	Training loss: 0.0467	Test loss: 19.5986	Test accuracy: 0.9333.
# Training teacher classifier: 188...
# Epoch: 5	Training loss: 48.4397	Test loss: 83.6819	Test accuracy: 0.5667.
# Epoch: 10	Training loss: 12.6687	Test loss: 67.2723	Test accuracy: 0.6667.
# Epoch: 15	Training loss: 3.9642	Test loss: 78.9529	Test accuracy: 0.7167.
# Epoch: 20	Training loss: 1.3476	Test loss: 97.8308	Test accuracy: 0.6667.
# Epoch: 25	Training loss: 1.2157	Test loss: 79.6217	Test accuracy: 0.7500.
# Epoch: 30	Training loss: 0.2146	Test loss: 78.3445	Test accuracy: 0.7667.
# Epoch: 35	Training loss: 0.0749	Test loss: 89.7516	Test accuracy: 0.7667.
# Epoch: 40	Training loss: 0.0476	Test loss: 90.5370	Test accuracy: 0.7667.
# Epoch: 45	Training loss: 0.0366	Test loss: 93.5826	Test accuracy: 0.7667.
# Epoch: 50	Training loss: 0.0303	Test loss: 95.4087	Test accuracy: 0.7667.
# Epoch: 55	Training loss: 0.0262	Test loss: 96.1823	Test accuracy: 0.7667.
# Epoch: 60	Training loss: 0.0228	Test loss: 97.2592	Test accuracy: 0.7667.
# Training teacher classifier: 189...
# Epoch: 5	Training loss: 45.5171	Test loss: 60.4523	Test accuracy: 0.6167.
# Epoch: 10	Training loss: 17.9459	Test loss: 36.7315	Test accuracy: 0.8333.
# Epoch: 15	Training loss: 5.6320	Test loss: 40.1980	Test accuracy: 0.8167.
# Epoch: 20	Training loss: 0.8003	Test loss: 46.4286	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.2924	Test loss: 44.8345	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.1598	Test loss: 48.5905	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.1092	Test loss: 49.8986	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.0813	Test loss: 50.2736	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.0640	Test loss: 51.3027	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0517	Test loss: 52.9739	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0422	Test loss: 53.5549	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0357	Test loss: 53.9572	Test accuracy: 0.8333.
# Training teacher classifier: 190...
# Epoch: 5	Training loss: 50.5332	Test loss: 42.8774	Test accuracy: 0.7667.
# Epoch: 10	Training loss: 12.8631	Test loss: 26.4665	Test accuracy: 0.8667.
# Epoch: 15	Training loss: 1.9641	Test loss: 20.1953	Test accuracy: 0.9333.
# Epoch: 20	Training loss: 0.5059	Test loss: 24.2307	Test accuracy: 0.9333.
# Epoch: 25	Training loss: 0.1781	Test loss: 24.7050	Test accuracy: 0.9333.
# Epoch: 30	Training loss: 0.1084	Test loss: 23.9374	Test accuracy: 0.9500.
# Epoch: 35	Training loss: 0.0783	Test loss: 25.3184	Test accuracy: 0.9500.
# Epoch: 40	Training loss: 0.0577	Test loss: 26.0575	Test accuracy: 0.9333.
# Epoch: 45	Training loss: 0.0454	Test loss: 26.6889	Test accuracy: 0.9333.
# Epoch: 50	Training loss: 0.0373	Test loss: 27.4126	Test accuracy: 0.9333.
# Epoch: 55	Training loss: 0.0299	Test loss: 27.4665	Test accuracy: 0.9500.
# Epoch: 60	Training loss: 0.0253	Test loss: 27.6594	Test accuracy: 0.9500.
# Training teacher classifier: 191...
# Epoch: 5	Training loss: 51.9359	Test loss: 67.9289	Test accuracy: 0.6167.
# Epoch: 10	Training loss: 17.6567	Test loss: 38.4531	Test accuracy: 0.8667.
# Epoch: 15	Training loss: 5.3567	Test loss: 41.5582	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 1.2263	Test loss: 46.1543	Test accuracy: 0.8167.
# Epoch: 25	Training loss: 0.3416	Test loss: 51.9067	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.1843	Test loss: 55.2012	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.1268	Test loss: 56.8390	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.0986	Test loss: 57.5572	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.0783	Test loss: 59.5195	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0643	Test loss: 60.9886	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0543	Test loss: 61.4324	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0460	Test loss: 62.7615	Test accuracy: 0.8333.
# Training teacher classifier: 192...
# Epoch: 5	Training loss: 59.8560	Test loss: 76.3723	Test accuracy: 0.6333.
# Epoch: 10	Training loss: 19.9705	Test loss: 38.3368	Test accuracy: 0.8167.
# Epoch: 15	Training loss: 6.1941	Test loss: 37.4297	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 2.6884	Test loss: 46.7524	Test accuracy: 0.8000.
# Epoch: 25	Training loss: 0.5939	Test loss: 54.5733	Test accuracy: 0.8167.
# Epoch: 30	Training loss: 0.2581	Test loss: 52.6091	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.1488	Test loss: 56.3839	Test accuracy: 0.8000.
# Epoch: 40	Training loss: 0.1082	Test loss: 57.9828	Test accuracy: 0.8167.
# Epoch: 45	Training loss: 0.0852	Test loss: 59.6015	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0691	Test loss: 61.7188	Test accuracy: 0.8167.
# Epoch: 55	Training loss: 0.0575	Test loss: 63.4439	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0484	Test loss: 63.7293	Test accuracy: 0.8167.
# Training teacher classifier: 193...
# Epoch: 5	Training loss: 64.9432	Test loss: 73.3198	Test accuracy: 0.5500.
# Epoch: 10	Training loss: 24.5228	Test loss: 54.1031	Test accuracy: 0.7167.
# Epoch: 15	Training loss: 11.5734	Test loss: 48.9827	Test accuracy: 0.7667.
# Epoch: 20	Training loss: 3.0757	Test loss: 44.6297	Test accuracy: 0.7500.
# Epoch: 25	Training loss: 0.8447	Test loss: 50.3440	Test accuracy: 0.7833.
# Epoch: 30	Training loss: 0.4593	Test loss: 48.4426	Test accuracy: 0.8000.
# Epoch: 35	Training loss: 0.2184	Test loss: 49.9039	Test accuracy: 0.8000.
# Epoch: 40	Training loss: 0.1565	Test loss: 51.1678	Test accuracy: 0.8000.
# Epoch: 45	Training loss: 0.1182	Test loss: 51.3931	Test accuracy: 0.8167.
# Epoch: 50	Training loss: 0.0967	Test loss: 52.1877	Test accuracy: 0.8000.
# Epoch: 55	Training loss: 0.0775	Test loss: 52.4259	Test accuracy: 0.8167.
# Epoch: 60	Training loss: 0.0654	Test loss: 53.5084	Test accuracy: 0.8000.
# Training teacher classifier: 194...
# Epoch: 5	Training loss: 57.8753	Test loss: 75.2616	Test accuracy: 0.6000.
# Epoch: 10	Training loss: 10.8462	Test loss: 51.0243	Test accuracy: 0.7833.
# Epoch: 15	Training loss: 3.3248	Test loss: 43.7065	Test accuracy: 0.8333.
# Epoch: 20	Training loss: 0.3474	Test loss: 41.0222	Test accuracy: 0.8333.
# Epoch: 25	Training loss: 0.1469	Test loss: 49.8790	Test accuracy: 0.8333.
# Epoch: 30	Training loss: 0.0799	Test loss: 47.5779	Test accuracy: 0.8333.
# Epoch: 35	Training loss: 0.0599	Test loss: 47.5651	Test accuracy: 0.8333.
# Epoch: 40	Training loss: 0.0490	Test loss: 48.9063	Test accuracy: 0.8333.
# Epoch: 45	Training loss: 0.0412	Test loss: 49.2102	Test accuracy: 0.8333.
# Epoch: 50	Training loss: 0.0355	Test loss: 49.8190	Test accuracy: 0.8333.
# Epoch: 55	Training loss: 0.0305	Test loss: 50.2065	Test accuracy: 0.8333.
# Epoch: 60	Training loss: 0.0264	Test loss: 50.1679	Test accuracy: 0.8333.
# Training teacher classifier: 195...
# Epoch: 5	Training loss: 41.3393	Test loss: 51.9165	Test accuracy: 0.7000.
# Epoch: 10	Training loss: 6.0457	Test loss: 22.9160	Test accuracy: 0.9333.
# Epoch: 15	Training loss: 1.8509	Test loss: 22.2554	Test accuracy: 0.9500.
# Epoch: 20	Training loss: 0.2796	Test loss: 21.8079	Test accuracy: 0.9333.
# Epoch: 25	Training loss: 0.0905	Test loss: 21.8240	Test accuracy: 0.9667.
# Epoch: 30	Training loss: 0.0569	Test loss: 22.9331	Test accuracy: 0.9500.
# Epoch: 35	Training loss: 0.0440	Test loss: 23.1145	Test accuracy: 0.9500.
# Epoch: 40	Training loss: 0.0360	Test loss: 23.4384	Test accuracy: 0.9500.
# Epoch: 45	Training loss: 0.0306	Test loss: 23.7197	Test accuracy: 0.9500.
# Epoch: 50	Training loss: 0.0262	Test loss: 24.2321	Test accuracy: 0.9500.
# Epoch: 55	Training loss: 0.0227	Test loss: 24.6063	Test accuracy: 0.9500.
# Epoch: 60	Training loss: 0.0201	Test loss: 24.8366	Test accuracy: 0.9500.
# Training teacher classifier: 196...
# Epoch: 5	Training loss: 46.2783	Test loss: 49.9994	Test accuracy: 0.7333.
# Epoch: 10	Training loss: 7.8949	Test loss: 36.1296	Test accuracy: 0.8167.
# Epoch: 15	Training loss: 1.6009	Test loss: 31.2226	Test accuracy: 0.8500.
# Epoch: 20	Training loss: 0.2872	Test loss: 32.8590	Test accuracy: 0.8833.
# Epoch: 25	Training loss: 0.1054	Test loss: 35.0239	Test accuracy: 0.8667.
# Epoch: 30	Training loss: 0.0686	Test loss: 34.3527	Test accuracy: 0.8667.
# Epoch: 35	Training loss: 0.0533	Test loss: 35.1619	Test accuracy: 0.8667.
# Epoch: 40	Training loss: 0.0433	Test loss: 35.0004	Test accuracy: 0.8667.
# Epoch: 45	Training loss: 0.0362	Test loss: 35.7556	Test accuracy: 0.8667.
# Epoch: 50	Training loss: 0.0308	Test loss: 35.9518	Test accuracy: 0.8667.
# Epoch: 55	Training loss: 0.0266	Test loss: 36.1869	Test accuracy: 0.8667.
# Epoch: 60	Training loss: 0.0231	Test loss: 36.2870	Test accuracy: 0.8667.
# Training teacher classifier: 197...
# Epoch: 5	Training loss: 38.8064	Test loss: 48.8758	Test accuracy: 0.7000.
# Epoch: 10	Training loss: 3.1407	Test loss: 17.1336	Test accuracy: 0.9000.
# Epoch: 15	Training loss: 0.5116	Test loss: 13.3016	Test accuracy: 0.9500.
# Epoch: 20	Training loss: 0.1269	Test loss: 12.7288	Test accuracy: 0.9500.
# Epoch: 25	Training loss: 0.0730	Test loss: 13.4440	Test accuracy: 0.9500.
# Epoch: 30	Training loss: 0.0529	Test loss: 13.0244	Test accuracy: 0.9500.
# Epoch: 35	Training loss: 0.0420	Test loss: 13.0125	Test accuracy: 0.9500.
# Epoch: 40	Training loss: 0.0348	Test loss: 12.7905	Test accuracy: 0.9500.
# Epoch: 45	Training loss: 0.0294	Test loss: 12.6805	Test accuracy: 0.9500.
# Epoch: 50	Training loss: 0.0251	Test loss: 12.6974	Test accuracy: 0.9500.
# Epoch: 55	Training loss: 0.0218	Test loss: 12.5850	Test accuracy: 0.9500.
# Epoch: 60	Training loss: 0.0191	Test loss: 12.6149	Test accuracy: 0.9500.
# Training teacher classifier: 198...
# Epoch: 5	Training loss: 30.6293	Test loss: 33.5625	Test accuracy: 0.8000.
# Epoch: 10	Training loss: 5.2596	Test loss: 9.4532	Test accuracy: 0.9333.
# Epoch: 15	Training loss: 0.8124	Test loss: 7.5407	Test accuracy: 0.9500.
# Epoch: 20	Training loss: 0.2816	Test loss: 5.4705	Test accuracy: 0.9667.
# Epoch: 25	Training loss: 0.1165	Test loss: 5.7253	Test accuracy: 0.9667.
# Epoch: 30	Training loss: 0.0799	Test loss: 6.2481	Test accuracy: 0.9667.
# Epoch: 35	Training loss: 0.0619	Test loss: 5.7203	Test accuracy: 0.9667.
# Epoch: 40	Training loss: 0.0504	Test loss: 5.6279	Test accuracy: 0.9667.
# Epoch: 45	Training loss: 0.0423	Test loss: 5.5418	Test accuracy: 0.9667.
# Epoch: 50	Training loss: 0.0359	Test loss: 5.6262	Test accuracy: 0.9667.
# Epoch: 55	Training loss: 0.0308	Test loss: 5.5449	Test accuracy: 0.9667.
# Epoch: 60	Training loss: 0.0269	Test loss: 5.3309	Test accuracy: 0.9667.
# Training teacher classifier: 199...
# Epoch: 5	Training loss: 39.6079	Test loss: 52.8857	Test accuracy: 0.7500.
# Epoch: 10	Training loss: 9.8155	Test loss: 34.6427	Test accuracy: 0.8333.
# Epoch: 15	Training loss: 1.5060	Test loss: 32.6024	Test accuracy: 0.9000.
# Epoch: 20	Training loss: 0.2646	Test loss: 27.4474	Test accuracy: 0.9167.
# Epoch: 25	Training loss: 0.1045	Test loss: 31.2066	Test accuracy: 0.9167.
# Epoch: 30	Training loss: 0.0711	Test loss: 30.0257	Test accuracy: 0.9167.
# Epoch: 35	Training loss: 0.0553	Test loss: 31.7474	Test accuracy: 0.9167.
# Epoch: 40	Training loss: 0.0453	Test loss: 31.9839	Test accuracy: 0.9167.
# Epoch: 45	Training loss: 0.0381	Test loss: 32.4947	Test accuracy: 0.9167.
# Epoch: 50	Training loss: 0.0327	Test loss: 32.7930	Test accuracy: 0.9167.
# Epoch: 55	Training loss: 0.0281	Test loss: 33.3411	Test accuracy: 0.9167.
# Epoch: 60	Training loss: 0.0249	Test loss: 33.5657	Test accuracy: 0.9167.
# Training teacher classifier: 200...
# Epoch: 5	Training loss: 46.1714	Test loss: 50.4531	Test accuracy: 0.6500.
# Epoch: 10	Training loss: 13.2454	Test loss: 21.9891	Test accuracy: 0.8833.
# Epoch: 15	Training loss: 4.5285	Test loss: 26.7112	Test accuracy: 0.8000.
# Epoch: 20	Training loss: 0.7992	Test loss: 23.8845	Test accuracy: 0.8667.
# Epoch: 25	Training loss: 0.2413	Test loss: 21.6802	Test accuracy: 0.8500.
# Epoch: 30	Training loss: 0.1164	Test loss: 26.5473	Test accuracy: 0.8667.
# Epoch: 35	Training loss: 0.0811	Test loss: 24.4371	Test accuracy: 0.8667.
# Epoch: 40	Training loss: 0.0651	Test loss: 25.3323	Test accuracy: 0.8667.
# Epoch: 45	Training loss: 0.0548	Test loss: 25.9975	Test accuracy: 0.8667.
# Epoch: 50	Training loss: 0.0466	Test loss: 26.1790	Test accuracy: 0.8667.
# Epoch: 55	Training loss: 0.0404	Test loss: 26.5419	Test accuracy: 0.8667.
# Epoch: 60	Training loss: 0.0353	Test loss: 27.0669	Test accuracy: 0.8667.

# %%
# save 200 classifiers

all_points = []

for i in range(len(classifiers)):
    all_points.append(classifiers[i].state_dict())
    
checkpoint = {'classifiers_list': all_points}
torch.save(checkpoint, 'checkpoints/teachers_checkpoint.pth')

# %%
# load checkpoint

checkpoint = torch.load('checkpoints/teachers_checkpoint.pth')
all_points = checkpoint['classifiers_list']

for i in range(num_teachers):
    classifiers[i] = Teacher()
    
for i in range(len(all_points)):
    classifiers[i].load_state_dict(all_points[i])

# %% [markdown]
# ### Predict labels for student data

# %% [markdown]
# I split student data into train and test part.

# %%
# split student data into 80% train and 20% test set
num_samples = len(student_data)
indices = list(range(num_samples))
np.random.shuffle(indices)
split = int(np.floor(0.2 * num_samples))
train_index, test_index = indices[split:], indices[:split]

# define samplers for obtaining training and test batches
train_sampler = SubsetRandomSampler(train_index)
test_sampler = SubsetRandomSampler(test_index)

# create dataloader
student_trainloader = DataLoader(student_data, batch_size=batch_size, sampler=train_sampler)
student_testloader = DataLoader(student_data, batch_size=batch_size, sampler=test_sampler)

# %%
predicted_labels = np.zeros((num_teachers, len(train_index)))

true_labels = np.zeros(len(train_index))

# %%
# predict labels for student training data

for i in range(num_teachers):
    classifier = classifiers[i]
    criterion = nn.NLLLoss()

    classifier.eval()
    test_loss = 0

    with torch.no_grad():
        start_index = 0
        for data, label in student_trainloader:
            output = classifier(data)
            loss = criterion(output, label)
            test_loss += loss.item()*data.size(0)

            
            ps = torch.exp(output)
            top_p, top_class = ps.topk(1, dim=1)
            
            predicted_labels[i, start_index: (start_index+batch_size)] = top_class.numpy().squeeze().astype(int)
            true_labels[start_index: (start_index+batch_size)] = label.numpy().astype(int)
            start_index += batch_size

# %%
true_labels = true_labels.astype(int)
predicted_labels = predicted_labels.astype(int)

# %%
indices = []
for i in range(predicted_labels.shape[1]): # iterate over each examples
    
    labels = predicted_labels[:, i]
    counts = np.bincount(labels, minlength=10)
    indices.append(np.argmax(counts))

# %% [markdown]
# PATE analysis

# %%
from syft.frameworks.torch.dp import pate
# Out:
# C:\Users\Phuong\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Phuong\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Phuong\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Phuong\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Phuong\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Phuong\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=predicted_labels, indices=np.array(indices), noise_eps=0.1, delta=1e-6)
print("Data Independent Epsilon:", data_ind_eps)
print("Data Dependent Epsilon:", data_dep_eps)
# Out:
# Data Independent Epsilon: 333.81551055796433
# Data Dependent Epsilon: 333.81551055798036

# %%
# add noise to predictions
indices = []
epsilon = 0.1
beta = 1/ epsilon

for i in range(predicted_labels.shape[1]): # iterate over each examples
    
    labels = predicted_labels[:, i] # this is all predicted labels of an example
    
    counts = np.bincount(labels, minlength=10)
    for i in range(len(counts)):
        counts[i] += np.random.laplace(0, beta, size=1)
    indices.append(np.argmax(counts))

# %%
data_dep_eps, data_ind_eps = pate.perform_analysis(teacher_preds=predicted_labels, indices=np.array(indices), noise_eps=0.1, delta=1e-6)
print("Data Independent Epsilon:", data_ind_eps)
print("Data Dependent Epsilon:", data_dep_eps)
# Out:
# Data Independent Epsilon: 333.81551055796433
# Data Dependent Epsilon: 333.81551055798036

# %% [markdown]
# ### Train student model using predicted labels from teacher classifiers
